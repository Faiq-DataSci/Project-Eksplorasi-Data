# %% [markdown]
# # SINGLE MOVING AVERAGE 3 BULAN

# %%
# ==========================================
# IMPORT LIBRARY
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt

# ==========================================
# MEMBACA FILE EXCEL
# ==========================================

df = pd.read_excel(
    "Data.xlsx",
    sheet_name="Harga_Beras"
)

# print("================ DATA AWAL ================")
# display(df.style.hide(axis="index"))

# ==========================================
# SINGLE MOVING AVERAGE 3 BULAN
# ==========================================

periode = 3

# Nilai St (Forecast)
df["St"] = (
    df["Harga Beras (Rp) (Y)"]
    .rolling(window=periode)
    .mean()
    .shift(1)
)

# ==========================================
# MENGHITUNG ERROR
# ==========================================

# Error
df["Xt-St"] = df["Harga Beras (Rp) (Y)"] - df["St"]

# Nilai Absolut Error
df["|Xt-St|"] = df["Xt-St"].abs()

# Kuadrat Error
df["(Xt-St)^2"] = df["Xt-St"] ** 2

# Absolute Percentage Error
df["APE (%)"] = (df["|Xt-St|"] / df["Harga Beras (Rp) (Y)"]) * 100

print("\n===== HASIL SINGLE MOVING AVERAGE 3 BULAN =====")
display(df.style.hide(axis="index"))

# ==========================================
# MENGHITUNG MAE, MSE, DAN MAPE
# ==========================================

hasil = df.dropna()

mae = hasil["|Xt-St|"].mean()

mse = hasil["(Xt-St)^2"].mean()

mape = hasil["APE (%)"].mean()

print("\n===== HASIL EVALUASI =====")
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"MAPE : {mape:.2f}%")

# ==========================================
# VISUALISASI
# ==========================================

plt.figure(figsize=(10,5))

plt.plot(
    df["Bulan"],
    df["Harga Beras (Rp) (Y)"],
    marker='o',
    linewidth=2,
    label="Data Aktual"
)

plt.plot(
    df["Bulan"],
    df["St"],
    marker='s',
    linewidth=2,
    label="Single Moving Average"
)

plt.title("Single Moving Average Harga Beras")
plt.xlabel("Bulan")
plt.ylabel("Harga Beras (Rp)")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== HASIL SINGLE MOVING AVERAGE 3 BULAN =====
# <style type="text/css">
# </style>
# <table id="T_cddc3">
#   <thead>
#     <tr>
#       <th id="T_cddc3_level0_col0" class="col_heading level0 col0" >Bulan</th>
#       <th id="T_cddc3_level0_col1" class="col_heading level0 col1" >Harga Beras (Rp) (Y)</th>
#       <th id="T_cddc3_level0_col2" class="col_heading level0 col2" >St</th>
#       <th id="T_cddc3_level0_col3" class="col_heading level0 col3" >Xt-St</th>
#       <th id="T_cddc3_level0_col4" class="col_heading level0 col4" >|Xt-St|</th>
#       <th id="T_cddc3_level0_col5" class="col_heading level0 col5" >(Xt-St)^2</th>
#       <th id="T_cddc3_level0_col6" class="col_heading level0 col6" >APE (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cddc3_row0_col0" class="data row0 col0" >2018-01-01 00:00:00</td>
#       <td id="T_cddc3_row0_col1" class="data row0 col1" >12276.000000</td>
#       <td id="T_cddc3_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_cddc3_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_cddc3_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_cddc3_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_cddc3_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row1_col0" class="data row1 col0" >2018-02-01 00:00:00</td>
#       <td id="T_cddc3_row1_col1" class="data row1 col1" >12414.000000</td>
#       <td id="T_cddc3_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_cddc3_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_cddc3_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_cddc3_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_cddc3_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row2_col0" class="data row2 col0" >2018-03-01 00:00:00</td>
#       <td id="T_cddc3_row2_col1" class="data row2 col1" >12299.000000</td>
#       <td id="T_cddc3_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_cddc3_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_cddc3_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_cddc3_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_cddc3_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row3_col0" class="data row3 col0" >2018-04-01 00:00:00</td>
#       <td id="T_cddc3_row3_col1" class="data row3 col1" >12035.000000</td>
#       <td id="T_cddc3_row3_col2" class="data row3 col2" >12329.666667</td>
#       <td id="T_cddc3_row3_col3" class="data row3 col3" >-294.666667</td>
#       <td id="T_cddc3_row3_col4" class="data row3 col4" >294.666667</td>
#       <td id="T_cddc3_row3_col5" class="data row3 col5" >86828.444444</td>
#       <td id="T_cddc3_row3_col6" class="data row3 col6" >2.448414</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row4_col0" class="data row4 col0" >2018-05-01 00:00:00</td>
#       <td id="T_cddc3_row4_col1" class="data row4 col1" >11943.000000</td>
#       <td id="T_cddc3_row4_col2" class="data row4 col2" >12249.333333</td>
#       <td id="T_cddc3_row4_col3" class="data row4 col3" >-306.333333</td>
#       <td id="T_cddc3_row4_col4" class="data row4 col4" >306.333333</td>
#       <td id="T_cddc3_row4_col5" class="data row4 col5" >93840.111111</td>
#       <td id="T_cddc3_row4_col6" class="data row4 col6" >2.564961</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row5_col0" class="data row5 col0" >2018-06-01 00:00:00</td>
#       <td id="T_cddc3_row5_col1" class="data row5 col1" >11907.260000</td>
#       <td id="T_cddc3_row5_col2" class="data row5 col2" >12092.333333</td>
#       <td id="T_cddc3_row5_col3" class="data row5 col3" >-185.073333</td>
#       <td id="T_cddc3_row5_col4" class="data row5 col4" >185.073333</td>
#       <td id="T_cddc3_row5_col5" class="data row5 col5" >34252.138711</td>
#       <td id="T_cddc3_row5_col6" class="data row5 col6" >1.554290</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row6_col0" class="data row6 col0" >2018-07-01 00:00:00</td>
#       <td id="T_cddc3_row6_col1" class="data row6 col1" >11936.000000</td>
#       <td id="T_cddc3_row6_col2" class="data row6 col2" >11961.753333</td>
#       <td id="T_cddc3_row6_col3" class="data row6 col3" >-25.753333</td>
#       <td id="T_cddc3_row6_col4" class="data row6 col4" >25.753333</td>
#       <td id="T_cddc3_row6_col5" class="data row6 col5" >663.234178</td>
#       <td id="T_cddc3_row6_col6" class="data row6 col6" >0.215762</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row7_col0" class="data row7 col0" >2018-08-01 00:00:00</td>
#       <td id="T_cddc3_row7_col1" class="data row7 col1" >11899.000000</td>
#       <td id="T_cddc3_row7_col2" class="data row7 col2" >11928.753333</td>
#       <td id="T_cddc3_row7_col3" class="data row7 col3" >-29.753333</td>
#       <td id="T_cddc3_row7_col4" class="data row7 col4" >29.753333</td>
#       <td id="T_cddc3_row7_col5" class="data row7 col5" >885.260844</td>
#       <td id="T_cddc3_row7_col6" class="data row7 col6" >0.250049</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row8_col0" class="data row8 col0" >2018-09-01 00:00:00</td>
#       <td id="T_cddc3_row8_col1" class="data row8 col1" >11900.000000</td>
#       <td id="T_cddc3_row8_col2" class="data row8 col2" >11914.086667</td>
#       <td id="T_cddc3_row8_col3" class="data row8 col3" >-14.086667</td>
#       <td id="T_cddc3_row8_col4" class="data row8 col4" >14.086667</td>
#       <td id="T_cddc3_row8_col5" class="data row8 col5" >198.434178</td>
#       <td id="T_cddc3_row8_col6" class="data row8 col6" >0.118375</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row9_col0" class="data row9 col0" >2018-10-01 00:00:00</td>
#       <td id="T_cddc3_row9_col1" class="data row9 col1" >11926.210000</td>
#       <td id="T_cddc3_row9_col2" class="data row9 col2" >11911.666667</td>
#       <td id="T_cddc3_row9_col3" class="data row9 col3" >14.543333</td>
#       <td id="T_cddc3_row9_col4" class="data row9 col4" >14.543333</td>
#       <td id="T_cddc3_row9_col5" class="data row9 col5" >211.508544</td>
#       <td id="T_cddc3_row9_col6" class="data row9 col6" >0.121944</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row10_col0" class="data row10 col0" >2018-11-01 00:00:00</td>
#       <td id="T_cddc3_row10_col1" class="data row10 col1" >12013.000000</td>
#       <td id="T_cddc3_row10_col2" class="data row10 col2" >11908.403333</td>
#       <td id="T_cddc3_row10_col3" class="data row10 col3" >104.596667</td>
#       <td id="T_cddc3_row10_col4" class="data row10 col4" >104.596667</td>
#       <td id="T_cddc3_row10_col5" class="data row10 col5" >10940.462678</td>
#       <td id="T_cddc3_row10_col6" class="data row10 col6" >0.870696</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row11_col0" class="data row11 col0" >2018-12-01 00:00:00</td>
#       <td id="T_cddc3_row11_col1" class="data row11 col1" >12105.770000</td>
#       <td id="T_cddc3_row11_col2" class="data row11 col2" >11946.403333</td>
#       <td id="T_cddc3_row11_col3" class="data row11 col3" >159.366667</td>
#       <td id="T_cddc3_row11_col4" class="data row11 col4" >159.366667</td>
#       <td id="T_cddc3_row11_col5" class="data row11 col5" >25397.734444</td>
#       <td id="T_cddc3_row11_col6" class="data row11 col6" >1.316452</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row12_col0" class="data row12 col0" >2019-01-01 00:00:00</td>
#       <td id="T_cddc3_row12_col1" class="data row12 col1" >12211.090000</td>
#       <td id="T_cddc3_row12_col2" class="data row12 col2" >12014.993333</td>
#       <td id="T_cddc3_row12_col3" class="data row12 col3" >196.096667</td>
#       <td id="T_cddc3_row12_col4" class="data row12 col4" >196.096667</td>
#       <td id="T_cddc3_row12_col5" class="data row12 col5" >38453.902678</td>
#       <td id="T_cddc3_row12_col6" class="data row12 col6" >1.605890</td>
#     </tr>
#     <tr>
#       <td id="T_cddc3_row13_col0" class="data row13 col0" >2019-02-01 00:00:00</td>
#       <td id="T_cddc3_row13_col1" class="data row13 col1" >12222.000000</td>
#       <td id="T_cddc3_row13_col2" class="data row13 col2" >12109.953333</td>
#       <td id="T_cddc3_row13_col3" class="data row13 col3" >112.046667</td>
#       <td id="T_cddc3
# ===== HASIL EVALUASI =====
# MAE  : 198.65
# MSE  : 119520.93
# MAPE : 1.63%

# %% [markdown]
# # SINGLE MOVING AVERAGE 5 BULAN

# %%
# ==========================================
# IMPORT LIBRARY
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt

# ==========================================
# MEMBACA FILE EXCEL
# ==========================================

df = pd.read_excel(
    "Data.xlsx",
    sheet_name="Harga_Beras"
)

# print("================ DATA AWAL ================")
# display(df.style.hide(axis="index"))

# ==========================================
# SINGLE MOVING AVERAGE 5 BULAN
# ==========================================

periode = 5

# Nilai St (Forecast)
df["St"] = (
    df["Harga Beras (Rp) (Y)"]
    .rolling(window=periode)
    .mean()
    .shift(1)
)

# ==========================================
# MENGHITUNG ERROR
# ==========================================

# Error
df["Xt-St"] = df["Harga Beras (Rp) (Y)"] - df["St"]

# Nilai Absolut Error
df["|Xt-St|"] = df["Xt-St"].abs()

# Kuadrat Error
df["(Xt-St)^2"] = df["Xt-St"] ** 2

# Absolute Percentage Error
df["APE (%)"] = (df["|Xt-St|"] / df["Harga Beras (Rp) (Y)"]) * 100

print("\n===== HASIL SINGLE MOVING AVERAGE 5 BULAN =====")
display(df.style.hide(axis="index"))

# ==========================================
# MENGHITUNG MAE, MSE, DAN MAPE
# ==========================================

hasil = df.dropna()

mae = hasil["|Xt-St|"].mean()

mse = hasil["(Xt-St)^2"].mean()

mape = hasil["APE (%)"].mean()

print("\n===== HASIL EVALUASI =====")
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"MAPE : {mape:.2f}%")

# ==========================================
# VISUALISASI
# ==========================================

plt.figure(figsize=(10,5))

plt.plot(
    df["Bulan"],
    df["Harga Beras (Rp) (Y)"],
    marker='o',
    linewidth=2,
    label="Data Aktual"
)

plt.plot(
    df["Bulan"],
    df["St"],
    marker='s',
    linewidth=2,
    label="SMA 5 Bulan"
)

plt.title("Single Moving Average 5 Bulan Harga Beras")
plt.xlabel("Bulan")
plt.ylabel("Harga Beras (Rp)")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== HASIL SINGLE MOVING AVERAGE 5 BULAN =====
# <style type="text/css">
# </style>
# <table id="T_589fb">
#   <thead>
#     <tr>
#       <th id="T_589fb_level0_col0" class="col_heading level0 col0" >Bulan</th>
#       <th id="T_589fb_level0_col1" class="col_heading level0 col1" >Harga Beras (Rp) (Y)</th>
#       <th id="T_589fb_level0_col2" class="col_heading level0 col2" >St</th>
#       <th id="T_589fb_level0_col3" class="col_heading level0 col3" >Xt-St</th>
#       <th id="T_589fb_level0_col4" class="col_heading level0 col4" >|Xt-St|</th>
#       <th id="T_589fb_level0_col5" class="col_heading level0 col5" >(Xt-St)^2</th>
#       <th id="T_589fb_level0_col6" class="col_heading level0 col6" >APE (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_589fb_row0_col0" class="data row0 col0" >2018-01-01 00:00:00</td>
#       <td id="T_589fb_row0_col1" class="data row0 col1" >12276.000000</td>
#       <td id="T_589fb_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_589fb_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_589fb_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_589fb_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_589fb_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row1_col0" class="data row1 col0" >2018-02-01 00:00:00</td>
#       <td id="T_589fb_row1_col1" class="data row1 col1" >12414.000000</td>
#       <td id="T_589fb_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_589fb_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_589fb_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_589fb_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_589fb_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row2_col0" class="data row2 col0" >2018-03-01 00:00:00</td>
#       <td id="T_589fb_row2_col1" class="data row2 col1" >12299.000000</td>
#       <td id="T_589fb_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_589fb_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_589fb_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_589fb_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_589fb_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row3_col0" class="data row3 col0" >2018-04-01 00:00:00</td>
#       <td id="T_589fb_row3_col1" class="data row3 col1" >12035.000000</td>
#       <td id="T_589fb_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_589fb_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_589fb_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_589fb_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_589fb_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row4_col0" class="data row4 col0" >2018-05-01 00:00:00</td>
#       <td id="T_589fb_row4_col1" class="data row4 col1" >11943.000000</td>
#       <td id="T_589fb_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_589fb_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_589fb_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_589fb_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_589fb_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row5_col0" class="data row5 col0" >2018-06-01 00:00:00</td>
#       <td id="T_589fb_row5_col1" class="data row5 col1" >11907.260000</td>
#       <td id="T_589fb_row5_col2" class="data row5 col2" >12193.400000</td>
#       <td id="T_589fb_row5_col3" class="data row5 col3" >-286.140000</td>
#       <td id="T_589fb_row5_col4" class="data row5 col4" >286.140000</td>
#       <td id="T_589fb_row5_col5" class="data row5 col5" >81876.099600</td>
#       <td id="T_589fb_row5_col6" class="data row5 col6" >2.403072</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row6_col0" class="data row6 col0" >2018-07-01 00:00:00</td>
#       <td id="T_589fb_row6_col1" class="data row6 col1" >11936.000000</td>
#       <td id="T_589fb_row6_col2" class="data row6 col2" >12119.652000</td>
#       <td id="T_589fb_row6_col3" class="data row6 col3" >-183.652000</td>
#       <td id="T_589fb_row6_col4" class="data row6 col4" >183.652000</td>
#       <td id="T_589fb_row6_col5" class="data row6 col5" >33728.057104</td>
#       <td id="T_589fb_row6_col6" class="data row6 col6" >1.538639</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row7_col0" class="data row7 col0" >2018-08-01 00:00:00</td>
#       <td id="T_589fb_row7_col1" class="data row7 col1" >11899.000000</td>
#       <td id="T_589fb_row7_col2" class="data row7 col2" >12024.052000</td>
#       <td id="T_589fb_row7_col3" class="data row7 col3" >-125.052000</td>
#       <td id="T_589fb_row7_col4" class="data row7 col4" >125.052000</td>
#       <td id="T_589fb_row7_col5" class="data row7 col5" >15638.002704</td>
#       <td id="T_589fb_row7_col6" class="data row7 col6" >1.050945</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row8_col0" class="data row8 col0" >2018-09-01 00:00:00</td>
#       <td id="T_589fb_row8_col1" class="data row8 col1" >11900.000000</td>
#       <td id="T_589fb_row8_col2" class="data row8 col2" >11944.052000</td>
#       <td id="T_589fb_row8_col3" class="data row8 col3" >-44.052000</td>
#       <td id="T_589fb_row8_col4" class="data row8 col4" >44.052000</td>
#       <td id="T_589fb_row8_col5" class="data row8 col5" >1940.578704</td>
#       <td id="T_589fb_row8_col6" class="data row8 col6" >0.370185</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row9_col0" class="data row9 col0" >2018-10-01 00:00:00</td>
#       <td id="T_589fb_row9_col1" class="data row9 col1" >11926.210000</td>
#       <td id="T_589fb_row9_col2" class="data row9 col2" >11917.052000</td>
#       <td id="T_589fb_row9_col3" class="data row9 col3" >9.158000</td>
#       <td id="T_589fb_row9_col4" class="data row9 col4" >9.158000</td>
#       <td id="T_589fb_row9_col5" class="data row9 col5" >83.868964</td>
#       <td id="T_589fb_row9_col6" class="data row9 col6" >0.076789</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row10_col0" class="data row10 col0" >2018-11-01 00:00:00</td>
#       <td id="T_589fb_row10_col1" class="data row10 col1" >12013.000000</td>
#       <td id="T_589fb_row10_col2" class="data row10 col2" >11913.694000</td>
#       <td id="T_589fb_row10_col3" class="data row10 col3" >99.306000</td>
#       <td id="T_589fb_row10_col4" class="data row10 col4" >99.306000</td>
#       <td id="T_589fb_row10_col5" class="data row10 col5" >9861.681636</td>
#       <td id="T_589fb_row10_col6" class="data row10 col6" >0.826654</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row11_col0" class="data row11 col0" >2018-12-01 00:00:00</td>
#       <td id="T_589fb_row11_col1" class="data row11 col1" >12105.770000</td>
#       <td id="T_589fb_row11_col2" class="data row11 col2" >11934.842000</td>
#       <td id="T_589fb_row11_col3" class="data row11 col3" >170.928000</td>
#       <td id="T_589fb_row11_col4" class="data row11 col4" >170.928000</td>
#       <td id="T_589fb_row11_col5" class="data row11 col5" >29216.381184</td>
#       <td id="T_589fb_row11_col6" class="data row11 col6" >1.411955</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row12_col0" class="data row12 col0" >2019-01-01 00:00:00</td>
#       <td id="T_589fb_row12_col1" class="data row12 col1" >12211.090000</td>
#       <td id="T_589fb_row12_col2" class="data row12 col2" >11968.796000</td>
#       <td id="T_589fb_row12_col3" class="data row12 col3" >242.294000</td>
#       <td id="T_589fb_row12_col4" class="data row12 col4" >242.294000</td>
#       <td id="T_589fb_row12_col5" class="data row12 col5" >58706.382436</td>
#       <td id="T_589fb_row12_col6" class="data row12 col6" >1.984213</td>
#     </tr>
#     <tr>
#       <td id="T_589fb_row13_col0" class="data row13 col0" >2019-02-01 00:00:00</td>
#       <td id="T_589fb_row13_col1" class="data row13 col1" >12222.000000</td>
#       <td id="T_589fb_row13_col2" class="data row13 col2" >12031.214000</td>
#       <td id="T_589fb_row13_col3" class="data row13 col3" >190.786000</td>
#       <td id="T_589fb_row13_col4" class="data row13 col4" >190.786000</td>
#       <td id="T_589
# ===== HASIL EVALUASI =====
# MAE  : 266.65
# MSE  : 181000.01
# MAPE : 2.20%

# %% [markdown]
# # DOUBLE MOVING AVERAGE

# %%
# ==========================================
# IMPORT LIBRARY
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error
)

# ==========================================
# MEMBACA FILE EXCEL
# ==========================================

df = pd.read_excel(
    "Data.xlsx",
    sheet_name="Harga_Beras"
)

# print("===== DATA AWAL =====")
# display(df)

# ==========================================
# DOUBLE MOVING AVERAGE (3 BULAN)
# ==========================================

periode = 3

# Moving Average Pertama (M1)
df["M1"] = (
    df["Harga Beras (Rp) (Y)"]
    .rolling(window=periode)
    .mean()
)

# Moving Average Kedua (M2)
df["M2"] = (
    df["M1"]
    .rolling(window=periode)
    .mean()
)

# Nilai a
df["a"] = (2 * df["M1"]) - df["M2"]

# Nilai b
df["b"] = (2 / (periode - 1)) * (df["M1"] - df["M2"])

# Forecast periode berikutnya (m = 1)
df["Forecast"] = df["a"] + df["b"]

print("\n===== HASIL DOUBLE MOVING AVERAGE =====")
display(df.style.hide(axis="index"))

# ==========================================
# MENGHITUNG MAE, MSE DAN MAPE 
# ==========================================

hasil = df.dropna()

# Menghitung MAE
mae = mean_absolute_error(
    hasil["Harga Beras (Rp) (Y)"],
    hasil["Forecast"]
)

# Menghitung MSE
mse = mean_squared_error(
    hasil["Harga Beras (Rp) (Y)"],
    hasil["Forecast"]
)

# Menghitung MAPE
mape = mean_absolute_percentage_error(
    hasil["Harga Beras (Rp) (Y)"],
    hasil["Forecast"]
) * 100

print("\n===== HASIL EVALUASI =====")
print(f"MAE : {mae:.2f}")
print(f"MSE : {mse:.2f}")
print(f"MAPE : {mape:.2f}%")

# ==========================================
# VISUALISASI
# ==========================================

plt.figure(figsize=(10,5))

plt.plot(
    df["Bulan"],
    df["Harga Beras (Rp) (Y)"],
    marker='o',
    linewidth=2,
    label="Data Aktual"
)

plt.plot(
    df["Bulan"],
    df["Forecast"],
    marker='s',
    linewidth=2,
    label="Forecast DMA"
)

plt.title("Double Moving Average Harga Beras")
plt.xlabel("Bulan")
plt.ylabel("Harga Beras (Rp)")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== HASIL DOUBLE MOVING AVERAGE =====
# <style type="text/css">
# </style>
# <table id="T_8c494">
#   <thead>
#     <tr>
#       <th id="T_8c494_level0_col0" class="col_heading level0 col0" >Bulan</th>
#       <th id="T_8c494_level0_col1" class="col_heading level0 col1" >Harga Beras (Rp) (Y)</th>
#       <th id="T_8c494_level0_col2" class="col_heading level0 col2" >M1</th>
#       <th id="T_8c494_level0_col3" class="col_heading level0 col3" >M2</th>
#       <th id="T_8c494_level0_col4" class="col_heading level0 col4" >a</th>
#       <th id="T_8c494_level0_col5" class="col_heading level0 col5" >b</th>
#       <th id="T_8c494_level0_col6" class="col_heading level0 col6" >Forecast</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8c494_row0_col0" class="data row0 col0" >2018-01-01 00:00:00</td>
#       <td id="T_8c494_row0_col1" class="data row0 col1" >12276.000000</td>
#       <td id="T_8c494_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_8c494_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_8c494_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_8c494_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_8c494_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row1_col0" class="data row1 col0" >2018-02-01 00:00:00</td>
#       <td id="T_8c494_row1_col1" class="data row1 col1" >12414.000000</td>
#       <td id="T_8c494_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_8c494_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_8c494_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_8c494_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_8c494_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row2_col0" class="data row2 col0" >2018-03-01 00:00:00</td>
#       <td id="T_8c494_row2_col1" class="data row2 col1" >12299.000000</td>
#       <td id="T_8c494_row2_col2" class="data row2 col2" >12329.666667</td>
#       <td id="T_8c494_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_8c494_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_8c494_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_8c494_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row3_col0" class="data row3 col0" >2018-04-01 00:00:00</td>
#       <td id="T_8c494_row3_col1" class="data row3 col1" >12035.000000</td>
#       <td id="T_8c494_row3_col2" class="data row3 col2" >12249.333333</td>
#       <td id="T_8c494_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_8c494_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_8c494_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_8c494_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row4_col0" class="data row4 col0" >2018-05-01 00:00:00</td>
#       <td id="T_8c494_row4_col1" class="data row4 col1" >11943.000000</td>
#       <td id="T_8c494_row4_col2" class="data row4 col2" >12092.333333</td>
#       <td id="T_8c494_row4_col3" class="data row4 col3" >12223.777778</td>
#       <td id="T_8c494_row4_col4" class="data row4 col4" >11960.888889</td>
#       <td id="T_8c494_row4_col5" class="data row4 col5" >-131.444444</td>
#       <td id="T_8c494_row4_col6" class="data row4 col6" >11829.444444</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row5_col0" class="data row5 col0" >2018-06-01 00:00:00</td>
#       <td id="T_8c494_row5_col1" class="data row5 col1" >11907.260000</td>
#       <td id="T_8c494_row5_col2" class="data row5 col2" >11961.753333</td>
#       <td id="T_8c494_row5_col3" class="data row5 col3" >12101.140000</td>
#       <td id="T_8c494_row5_col4" class="data row5 col4" >11822.366667</td>
#       <td id="T_8c494_row5_col5" class="data row5 col5" >-139.386667</td>
#       <td id="T_8c494_row5_col6" class="data row5 col6" >11682.980000</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row6_col0" class="data row6 col0" >2018-07-01 00:00:00</td>
#       <td id="T_8c494_row6_col1" class="data row6 col1" >11936.000000</td>
#       <td id="T_8c494_row6_col2" class="data row6 col2" >11928.753333</td>
#       <td id="T_8c494_row6_col3" class="data row6 col3" >11994.280000</td>
#       <td id="T_8c494_row6_col4" class="data row6 col4" >11863.226667</td>
#       <td id="T_8c494_row6_col5" class="data row6 col5" >-65.526667</td>
#       <td id="T_8c494_row6_col6" class="data row6 col6" >11797.700000</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row7_col0" class="data row7 col0" >2018-08-01 00:00:00</td>
#       <td id="T_8c494_row7_col1" class="data row7 col1" >11899.000000</td>
#       <td id="T_8c494_row7_col2" class="data row7 col2" >11914.086667</td>
#       <td id="T_8c494_row7_col3" class="data row7 col3" >11934.864444</td>
#       <td id="T_8c494_row7_col4" class="data row7 col4" >11893.308889</td>
#       <td id="T_8c494_row7_col5" class="data row7 col5" >-20.777778</td>
#       <td id="T_8c494_row7_col6" class="data row7 col6" >11872.531111</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row8_col0" class="data row8 col0" >2018-09-01 00:00:00</td>
#       <td id="T_8c494_row8_col1" class="data row8 col1" >11900.000000</td>
#       <td id="T_8c494_row8_col2" class="data row8 col2" >11911.666667</td>
#       <td id="T_8c494_row8_col3" class="data row8 col3" >11918.168889</td>
#       <td id="T_8c494_row8_col4" class="data row8 col4" >11905.164444</td>
#       <td id="T_8c494_row8_col5" class="data row8 col5" >-6.502222</td>
#       <td id="T_8c494_row8_col6" class="data row8 col6" >11898.662222</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row9_col0" class="data row9 col0" >2018-10-01 00:00:00</td>
#       <td id="T_8c494_row9_col1" class="data row9 col1" >11926.210000</td>
#       <td id="T_8c494_row9_col2" class="data row9 col2" >11908.403333</td>
#       <td id="T_8c494_row9_col3" class="data row9 col3" >11911.385556</td>
#       <td id="T_8c494_row9_col4" class="data row9 col4" >11905.421111</td>
#       <td id="T_8c494_row9_col5" class="data row9 col5" >-2.982222</td>
#       <td id="T_8c494_row9_col6" class="data row9 col6" >11902.438889</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row10_col0" class="data row10 col0" >2018-11-01 00:00:00</td>
#       <td id="T_8c494_row10_col1" class="data row10 col1" >12013.000000</td>
#       <td id="T_8c494_row10_col2" class="data row10 col2" >11946.403333</td>
#       <td id="T_8c494_row10_col3" class="data row10 col3" >11922.157778</td>
#       <td id="T_8c494_row10_col4" class="data row10 col4" >11970.648889</td>
#       <td id="T_8c494_row10_col5" class="data row10 col5" >24.245556</td>
#       <td id="T_8c494_row10_col6" class="data row10 col6" >11994.894444</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row11_col0" class="data row11 col0" >2018-12-01 00:00:00</td>
#       <td id="T_8c494_row11_col1" class="data row11 col1" >12105.770000</td>
#       <td id="T_8c494_row11_col2" class="data row11 col2" >12014.993333</td>
#       <td id="T_8c494_row11_col3" class="data row11 col3" >11956.600000</td>
#       <td id="T_8c494_row11_col4" class="data row11 col4" >12073.386667</td>
#       <td id="T_8c494_row11_col5" class="data row11 col5" >58.393333</td>
#       <td id="T_8c494_row11_col6" class="data row11 col6" >12131.780000</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row12_col0" class="data row12 col0" >2019-01-01 00:00:00</td>
#       <td id="T_8c494_row12_col1" class="data row12 col1" >12211.090000</td>
#       <td id="T_8c494_row12_col2" class="data row12 col2" >12109.953333</td>
#       <td id="T_8c494_row12_col3" class="data row12 col3" >12023.783333</td>
#       <td id="T_8c494_row12_col4" class="data row12 col4" >12196.123333</td>
#       <td id="T_8c494_row12_col5" class="data row12 col5" >86.170000</td>
#       <td id="T_8c494_row12_col6" class="data row12 col6" >12282.293333</td>
#     </tr>
#     <tr>
#       <td id="T_8c494_row13_col0" class="data row13 col0" >2019-02-01 00:00:00</td>
#       <td id="T_8c494_row13_col1" class="data row13 col1" >12222.000000</td>
#       <td id="T_8c494_row13_col2" class="data row13 col2" >12179.620000</td>
#       <td id="T_8c494_row13_col3" class="data row13 col3" >12101.52222
# ===== HASIL EVALUASI =====
# MAE : 123.99
# MSE : 48625.74
# MAPE : 1.01%

# %% [markdown]
# # SINGLE EXPONENTIAL SMOOTHING

# %%
# ==========================================
# IMPORT LIBRARY
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error
)

# ==========================================
# MEMBACA FILE EXCEL
# ==========================================

df = pd.read_excel(
    "Data.xlsx",
    sheet_name="Harga_Beras"
)

# print("===== DATA AWAL =====")
# display(df.style.hide(axis="index"))

# ==========================================
# SINGLE EXPONENTIAL SMOOTHING
# ==========================================

# Mengubah Nilai Alpha (0.10) dan (0.50)
alpha = 0.5

# ==========================================
# PERHITUNGAN SINGLE EXPONENTIAL SMOOTHING
# ==========================================

# Kolom St (hasil smoothing)
df["St"] = 0.0

# Nilai awal St = data aktual pertama
df.loc[0, "St"] = df.loc[0, "Harga Beras (Rp) (Y)"]

# Menghitung nilai St
for i in range(1, len(df)):
    df.loc[i, "St"] = (
        alpha * df.loc[i-1, "Harga Beras (Rp) (Y)"]
        + (1 - alpha) * df.loc[i-1, "St"]
    )

# ==========================================
# PERHITUNGAN ERROR
# ==========================================

# Error
df["Xt-St"] = df["Harga Beras (Rp) (Y)"] - df["St"]

# Nilai Absolut Error
df["|Xt-St|"] = df["Xt-St"].abs()

# Kuadrat Error
df["(Xt-St)^2"] = df["Xt-St"] ** 2

print("\n===== HASIL SINGLE EXPONENTIAL SMOOTHING =====")
display(df.style.hide(axis="index"))

# ==========================================
# MENGHITUNG MAE, MSE, DAN MAPE
# ==========================================

hasil = df.iloc[1:]

mae = hasil["|Xt-St|"].mean()

mse = hasil["(Xt-St)^2"].mean()

mape = (
    (hasil["|Xt-St|"] / hasil["Harga Beras (Rp) (Y)"])
    .mean()
) * 100

print("\n===== HASIL EVALUASI =====")
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"MAPE : {mape:.2f}%")

# ==========================================
# VISUALISASI
# ==========================================

plt.figure(figsize=(10,5))

plt.plot(
    df["Bulan"],
    df["Harga Beras (Rp) (Y)"],
    marker='o',
    linewidth=2,
    label="Data Aktual"
)

plt.plot(
    df["Bulan"],
    df["St"],
    marker='s',
    linewidth=2,
    label=f"SES (α = {alpha})"
)

plt.title("Single Exponential Smoothing Harga Beras")
plt.xlabel("Bulan")
plt.ylabel("Harga Beras (Rp)")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== HASIL SINGLE EXPONENTIAL SMOOTHING =====
# <style type="text/css">
# </style>
# <table id="T_45e6a">
#   <thead>
#     <tr>
#       <th id="T_45e6a_level0_col0" class="col_heading level0 col0" >Bulan</th>
#       <th id="T_45e6a_level0_col1" class="col_heading level0 col1" >Harga Beras (Rp) (Y)</th>
#       <th id="T_45e6a_level0_col2" class="col_heading level0 col2" >St</th>
#       <th id="T_45e6a_level0_col3" class="col_heading level0 col3" >Xt-St</th>
#       <th id="T_45e6a_level0_col4" class="col_heading level0 col4" >|Xt-St|</th>
#       <th id="T_45e6a_level0_col5" class="col_heading level0 col5" >(Xt-St)^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_45e6a_row0_col0" class="data row0 col0" >2018-01-01 00:00:00</td>
#       <td id="T_45e6a_row0_col1" class="data row0 col1" >12276.000000</td>
#       <td id="T_45e6a_row0_col2" class="data row0 col2" >12276.000000</td>
#       <td id="T_45e6a_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_45e6a_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_45e6a_row0_col5" class="data row0 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row1_col0" class="data row1 col0" >2018-02-01 00:00:00</td>
#       <td id="T_45e6a_row1_col1" class="data row1 col1" >12414.000000</td>
#       <td id="T_45e6a_row1_col2" class="data row1 col2" >12276.000000</td>
#       <td id="T_45e6a_row1_col3" class="data row1 col3" >138.000000</td>
#       <td id="T_45e6a_row1_col4" class="data row1 col4" >138.000000</td>
#       <td id="T_45e6a_row1_col5" class="data row1 col5" >19044.000000</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row2_col0" class="data row2 col0" >2018-03-01 00:00:00</td>
#       <td id="T_45e6a_row2_col1" class="data row2 col1" >12299.000000</td>
#       <td id="T_45e6a_row2_col2" class="data row2 col2" >12345.000000</td>
#       <td id="T_45e6a_row2_col3" class="data row2 col3" >-46.000000</td>
#       <td id="T_45e6a_row2_col4" class="data row2 col4" >46.000000</td>
#       <td id="T_45e6a_row2_col5" class="data row2 col5" >2116.000000</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row3_col0" class="data row3 col0" >2018-04-01 00:00:00</td>
#       <td id="T_45e6a_row3_col1" class="data row3 col1" >12035.000000</td>
#       <td id="T_45e6a_row3_col2" class="data row3 col2" >12322.000000</td>
#       <td id="T_45e6a_row3_col3" class="data row3 col3" >-287.000000</td>
#       <td id="T_45e6a_row3_col4" class="data row3 col4" >287.000000</td>
#       <td id="T_45e6a_row3_col5" class="data row3 col5" >82369.000000</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row4_col0" class="data row4 col0" >2018-05-01 00:00:00</td>
#       <td id="T_45e6a_row4_col1" class="data row4 col1" >11943.000000</td>
#       <td id="T_45e6a_row4_col2" class="data row4 col2" >12178.500000</td>
#       <td id="T_45e6a_row4_col3" class="data row4 col3" >-235.500000</td>
#       <td id="T_45e6a_row4_col4" class="data row4 col4" >235.500000</td>
#       <td id="T_45e6a_row4_col5" class="data row4 col5" >55460.250000</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row5_col0" class="data row5 col0" >2018-06-01 00:00:00</td>
#       <td id="T_45e6a_row5_col1" class="data row5 col1" >11907.260000</td>
#       <td id="T_45e6a_row5_col2" class="data row5 col2" >12060.750000</td>
#       <td id="T_45e6a_row5_col3" class="data row5 col3" >-153.490000</td>
#       <td id="T_45e6a_row5_col4" class="data row5 col4" >153.490000</td>
#       <td id="T_45e6a_row5_col5" class="data row5 col5" >23559.180100</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row6_col0" class="data row6 col0" >2018-07-01 00:00:00</td>
#       <td id="T_45e6a_row6_col1" class="data row6 col1" >11936.000000</td>
#       <td id="T_45e6a_row6_col2" class="data row6 col2" >11984.005000</td>
#       <td id="T_45e6a_row6_col3" class="data row6 col3" >-48.005000</td>
#       <td id="T_45e6a_row6_col4" class="data row6 col4" >48.005000</td>
#       <td id="T_45e6a_row6_col5" class="data row6 col5" >2304.480025</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row7_col0" class="data row7 col0" >2018-08-01 00:00:00</td>
#       <td id="T_45e6a_row7_col1" class="data row7 col1" >11899.000000</td>
#       <td id="T_45e6a_row7_col2" class="data row7 col2" >11960.002500</td>
#       <td id="T_45e6a_row7_col3" class="data row7 col3" >-61.002500</td>
#       <td id="T_45e6a_row7_col4" class="data row7 col4" >61.002500</td>
#       <td id="T_45e6a_row7_col5" class="data row7 col5" >3721.305006</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row8_col0" class="data row8 col0" >2018-09-01 00:00:00</td>
#       <td id="T_45e6a_row8_col1" class="data row8 col1" >11900.000000</td>
#       <td id="T_45e6a_row8_col2" class="data row8 col2" >11929.501250</td>
#       <td id="T_45e6a_row8_col3" class="data row8 col3" >-29.501250</td>
#       <td id="T_45e6a_row8_col4" class="data row8 col4" >29.501250</td>
#       <td id="T_45e6a_row8_col5" class="data row8 col5" >870.323752</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row9_col0" class="data row9 col0" >2018-10-01 00:00:00</td>
#       <td id="T_45e6a_row9_col1" class="data row9 col1" >11926.210000</td>
#       <td id="T_45e6a_row9_col2" class="data row9 col2" >11914.750625</td>
#       <td id="T_45e6a_row9_col3" class="data row9 col3" >11.459375</td>
#       <td id="T_45e6a_row9_col4" class="data row9 col4" >11.459375</td>
#       <td id="T_45e6a_row9_col5" class="data row9 col5" >131.317275</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row10_col0" class="data row10 col0" >2018-11-01 00:00:00</td>
#       <td id="T_45e6a_row10_col1" class="data row10 col1" >12013.000000</td>
#       <td id="T_45e6a_row10_col2" class="data row10 col2" >11920.480312</td>
#       <td id="T_45e6a_row10_col3" class="data row10 col3" >92.519688</td>
#       <td id="T_45e6a_row10_col4" class="data row10 col4" >92.519688</td>
#       <td id="T_45e6a_row10_col5" class="data row10 col5" >8559.892575</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row11_col0" class="data row11 col0" >2018-12-01 00:00:00</td>
#       <td id="T_45e6a_row11_col1" class="data row11 col1" >12105.770000</td>
#       <td id="T_45e6a_row11_col2" class="data row11 col2" >11966.740156</td>
#       <td id="T_45e6a_row11_col3" class="data row11 col3" >139.029844</td>
#       <td id="T_45e6a_row11_col4" class="data row11 col4" >139.029844</td>
#       <td id="T_45e6a_row11_col5" class="data row11 col5" >19329.297453</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row12_col0" class="data row12 col0" >2019-01-01 00:00:00</td>
#       <td id="T_45e6a_row12_col1" class="data row12 col1" >12211.090000</td>
#       <td id="T_45e6a_row12_col2" class="data row12 col2" >12036.255078</td>
#       <td id="T_45e6a_row12_col3" class="data row12 col3" >174.834922</td>
#       <td id="T_45e6a_row12_col4" class="data row12 col4" >174.834922</td>
#       <td id="T_45e6a_row12_col5" class="data row12 col5" >30567.249907</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row13_col0" class="data row13 col0" >2019-02-01 00:00:00</td>
#       <td id="T_45e6a_row13_col1" class="data row13 col1" >12222.000000</td>
#       <td id="T_45e6a_row13_col2" class="data row13 col2" >12123.672539</td>
#       <td id="T_45e6a_row13_col3" class="data row13 col3" >98.327461</td>
#       <td id="T_45e6a_row13_col4" class="data row13 col4" >98.327461</td>
#       <td id="T_45e6a_row13_col5" class="data row13 col5" >9668.289574</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row14_col0" class="data row14 col0" >2019-03-01 00:00:00</td>
#       <td id="T_45e6a_row14_col1" class="data row14 col1" >12124.000000</td>
#       <td id="T_45e6a_row14_col2" class="data row14 col2" >12172.836270</td>
#       <td id="T_45e6a_row14_col3" class="data row14 col3" >-48.836270</td>
#       <td id="T_45e6a_row14_col4" class="data row14 col4" >48.836270</td>
#       <td id="T_45e6a_row14_col5" class="data row14 col5" >2384.981222</td>
#     </tr>
#     <tr>
#       <td id="T_45e6a_row15_col0" class="data row15 col0" >2019-04-01 00:00:00</td>
#       <td id="T_45e6a_row15_col1" class="data row15 col1" >12019.000000</td>
#       <td id="T_45e6a_row15_col2" class="data row15 col2" >12148.418135</td>
#       <td id="T_45e6a_row15_col3" class="da
# ===== HASIL EVALUASI =====
# MAE  : 183.14
# MSE  : 99349.35
# MAPE : 1.50%

# %% [markdown]
# # DOUBLE EXPONENTIAL SMOOTHING

# %%
# ==========================================
# IMPORT LIBRARY
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt

# ==========================================
# MEMBACA FILE EXCEL
# ==========================================

df = pd.read_excel(
    "Data.xlsx",
    sheet_name="Harga_Beras"
)

# print("================ DATA AWAL ================")
# display(df.style.hide(axis="index"))

# ==========================================
# PARAMETER
# ==========================================

alpha = 0.2

# ==========================================
# MEMBUAT KOLOM
# ==========================================

df["S't"] = 0.0
df["S''t"] = 0.0
df["a"] = 0.0
df["b"] = 0.0
df["Forecast"] = None

# ==========================================
# NILAI AWAL
# ==========================================

df.loc[0, "S't"] = df.loc[0, "Harga Beras (Rp) (Y)"]
df.loc[0, "S''t"] = df.loc[0, "Harga Beras (Rp) (Y)"]

# ==========================================
# PERHITUNGAN DOUBLE EXPONENTIAL SMOOTHING
# ==========================================

for i in range(1, len(df)):

    # Single Smoothing
    df.loc[i, "S't"] = (
        alpha * df.loc[i, "Harga Beras (Rp) (Y)"] +
        (1-alpha) * df.loc[i-1, "S't"]
    )

    # Double Smoothing
    df.loc[i, "S''t"] = (
        alpha * df.loc[i, "S't"] +
        (1-alpha) * df.loc[i-1, "S''t"]
    )

    # Nilai a
    df.loc[i, "a"] = (
        2 * df.loc[i, "S't"] -
        df.loc[i, "S''t"]
    )

    # Nilai b
    df.loc[i, "b"] = (
        alpha / (1-alpha)
    ) * (
        df.loc[i, "S't"] -
        df.loc[i, "S''t"]
    )

    # Forecast satu periode ke depan
    df.loc[i, "Forecast"] = (
        df.loc[i, "a"] +
        df.loc[i, "b"]
    )

# ==========================================
# MENGHITUNG ERROR
# ==========================================

df["Xt-Ft"] = (
    df["Harga Beras (Rp) (Y)"] -
    df["Forecast"]
)

df["|Xt-Ft|"] = df["Xt-Ft"].abs()

df["(Xt-Ft)^2"] = df["Xt-Ft"]**2

df["APE (%)"] = (
    df["|Xt-Ft|"] /
    df["Harga Beras (Rp) (Y)"]
) * 100

print("\n===== HASIL DOUBLE EXPONENTIAL SMOOTHING =====")
display(df.style.hide(axis="index"))

# ==========================================
# EVALUASI
# ==========================================

hasil = df.dropna()

mae = hasil["|Xt-Ft|"].mean()

mse = hasil["(Xt-Ft)^2"].mean()

mape = hasil["APE (%)"].mean()

print("\n===== HASIL EVALUASI =====")
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"MAPE : {mape:.2f}%")

# ==========================================
# VISUALISASI
# ==========================================

plt.figure(figsize=(10,5))

plt.plot(
    df["Bulan"],
    df["Harga Beras (Rp) (Y)"],
    marker='o',
    linewidth=2,
    label="Data Aktual"
)

plt.plot(
    df["Bulan"],
    df["Forecast"],
    marker='s',
    linewidth=2,
    label=f"DES Brown (α={alpha})"
)

plt.title("Double Exponential Smoothing Harga Beras")
plt.xlabel("Bulan")
plt.ylabel("Harga Beras (Rp)")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== HASIL DOUBLE EXPONENTIAL SMOOTHING =====
# <style type="text/css">
# </style>
# <table id="T_629a9">
#   <thead>
#     <tr>
#       <th id="T_629a9_level0_col0" class="col_heading level0 col0" >Bulan</th>
#       <th id="T_629a9_level0_col1" class="col_heading level0 col1" >Harga Beras (Rp) (Y)</th>
#       <th id="T_629a9_level0_col2" class="col_heading level0 col2" >S't</th>
#       <th id="T_629a9_level0_col3" class="col_heading level0 col3" >S''t</th>
#       <th id="T_629a9_level0_col4" class="col_heading level0 col4" >a</th>
#       <th id="T_629a9_level0_col5" class="col_heading level0 col5" >b</th>
#       <th id="T_629a9_level0_col6" class="col_heading level0 col6" >Forecast</th>
#       <th id="T_629a9_level0_col7" class="col_heading level0 col7" >Xt-Ft</th>
#       <th id="T_629a9_level0_col8" class="col_heading level0 col8" >|Xt-Ft|</th>
#       <th id="T_629a9_level0_col9" class="col_heading level0 col9" >(Xt-Ft)^2</th>
#       <th id="T_629a9_level0_col10" class="col_heading level0 col10" >APE (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_629a9_row0_col0" class="data row0 col0" >2018-01-01 00:00:00</td>
#       <td id="T_629a9_row0_col1" class="data row0 col1" >12276.000000</td>
#       <td id="T_629a9_row0_col2" class="data row0 col2" >12276.000000</td>
#       <td id="T_629a9_row0_col3" class="data row0 col3" >12276.000000</td>
#       <td id="T_629a9_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_629a9_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_629a9_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_629a9_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_629a9_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_629a9_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_629a9_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_629a9_row1_col0" class="data row1 col0" >2018-02-01 00:00:00</td>
#       <td id="T_629a9_row1_col1" class="data row1 col1" >12414.000000</td>
#       <td id="T_629a9_row1_col2" class="data row1 col2" >12303.600000</td>
#       <td id="T_629a9_row1_col3" class="data row1 col3" >12281.520000</td>
#       <td id="T_629a9_row1_col4" class="data row1 col4" >12325.680000</td>
#       <td id="T_629a9_row1_col5" class="data row1 col5" >5.520000</td>
#       <td id="T_629a9_row1_col6" class="data row1 col6" >12331.200000</td>
#       <td id="T_629a9_row1_col7" class="data row1 col7" >82.800000</td>
#       <td id="T_629a9_row1_col8" class="data row1 col8" >82.800000</td>
#       <td id="T_629a9_row1_col9" class="data row1 col9" >6855.840000</td>
#       <td id="T_629a9_row1_col10" class="data row1 col10" >0.666989</td>
#     </tr>
#     <tr>
#       <td id="T_629a9_row2_col0" class="data row2 col0" >2018-03-01 00:00:00</td>
#       <td id="T_629a9_row2_col1" class="data row2 col1" >12299.000000</td>
#       <td id="T_629a9_row2_col2" class="data row2 col2" >12302.680000</td>
#       <td id="T_629a9_row2_col3" class="data row2 col3" >12285.752000</td>
#       <td id="T_629a9_row2_col4" class="data row2 col4" >12319.608000</td>
#       <td id="T_629a9_row2_col5" class="data row2 col5" >4.232000</td>
#       <td id="T_629a9_row2_col6" class="data row2 col6" >12323.840000</td>
#       <td id="T_629a9_row2_col7" class="data row2 col7" >-24.840000</td>
#       <td id="T_629a9_row2_col8" class="data row2 col8" >24.840000</td>
#       <td id="T_629a9_row2_col9" class="data row2 col9" >617.025600</td>
#       <td id="T_629a9_row2_col10" class="data row2 col10" >0.201968</td>
#     </tr>
#     <tr>
#       <td id="T_629a9_row3_col0" class="data row3 col0" >2018-04-01 00:00:00</td>
#       <td id="T_629a9_row3_col1" class="data row3 col1" >12035.000000</td>
#       <td id="T_629a9_row3_col2" class="data row3 col2" >12249.144000</td>
#       <td id="T_629a9_row3_col3" class="data row3 col3" >12278.430400</td>
#       <td id="T_629a9_row3_col4" class="data row3 col4" >12219.857600</td>
#       <td id="T_629a9_row3_col5" class="data row3 col5" >-7.321600</td>
#       <td id="T_629a9_row3_col6" class="data row3 col6" >12212.536000</td>
#       <td id="T_629a9_row3_col7" class="data row3 col7" >-177.536000</td>
#       <td id="T_629a9_row3_col8" class="data row3 col8" >177.536000</td>
#       <td id="T_629a9_row3_col9" class="data row3 col9" >31519.031296</td>
#       <td id="T_629a9_row3_col10" class="data row3 col10" >1.475164</td>
#     </tr>
#     <tr>
#       <td id="T_629a9_row4_col0" class="data row4 col0" >2018-05-01 00:00:00</td>
#       <td id="T_629a9_row4_col1" class="data row4 col1" >11943.000000</td>
#       <td id="T_629a9_row4_col2" class="data row4 col2" >12187.915200</td>
#       <td id="T_629a9_row4_col3" class="data row4 col3" >12260.327360</td>
#       <td id="T_629a9_row4_col4" class="data row4 col4" >12115.503040</td>
#       <td id="T_629a9_row4_col5" class="data row4 col5" >-18.103040</td>
#       <td id="T_629a9_row4_col6" class="data row4 col6" >12097.400000</td>
#       <td id="T_629a9_row4_col7" class="data row4 col7" >-154.400000</td>
#       <td id="T_629a9_row4_col8" class="data row4 col8" >154.400000</td>
#       <td id="T_629a9_row4_col9" class="data row4 col9" >23839.360000</td>
#       <td id="T_629a9_row4_col10" class="data row4 col10" >1.292808</td>
#     </tr>
#     <tr>
#       <td id="T_629a9_row5_col0" class="data row5 col0" >2018-06-01 00:00:00</td>
#       <td id="T_629a9_row5_col1" class="data row5 col1" >11907.260000</td>
#       <td id="T_629a9_row5_col2" class="data row5 col2" >12131.784160</td>
#       <td id="T_629a9_row5_col3" class="data row5 col3" >12234.618720</td>
#       <td id="T_629a9_row5_col4" class="data row5 col4" >12028.949600</td>
#       <td id="T_629a9_row5_col5" class="data row5 col5" >-25.708640</td>
#       <td id="T_629a9_row5_col6" class="data row5 col6" >12003.240960</td>
#       <td id="T_629a9_row5_col7" class="data row5 col7" >-95.980960</td>
#       <td id="T_629a9_row5_col8" class="data row5 col8" >95.980960</td>
#       <td id="T_629a9_row5_col9" class="data row5 col9" >9212.344683</td>
#       <td id="T_629a9_row5_col10" class="data row5 col10" >0.806071</td>
#     </tr>
#     <tr>
#       <td id="T_629a9_row6_col0" class="data row6 col0" >2018-07-01 00:00:00</td>
#       <td id="T_629a9_row6_col1" class="data row6 col1" >11936.000000</td>
#       <td id="T_629a9_row6_col2" class="data row6 col2" >12092.627328</td>
#       <td id="T_629a9_row6_col3" class="data row6 col3" >12206.220442</td>
#       <td id="T_629a9_row6_col4" class="data row6 col4" >11979.034214</td>
#       <td id="T_629a9_row6_col5" class="data row6 col5" >-28.398278</td>
#       <td id="T_629a9_row6_col6" class="data row6 col6" >11950.635936</td>
#       <td id="T_629a9_row6_col7" class="data row6 col7" >-14.635936</td>
#       <td id="T_629a9_row6_col8" class="data row6 col8" >14.635936</td>
#       <td id="T_629a9_row6_col9" class="data row6 col9" >214.210623</td>
#       <td id="T_629a9_row6_col10" class="data row6 col10" >0.122620</td>
#     </tr>
#     <tr>
#       <td id="T_629a9_row7_col0" class="data row7 col0" >2018-08-01 00:00:00</td>
#       <td id="T_629a9_row7_col1" class="data row7 col1" >11899.000000</td>
#       <td id="T_629a9_row7_col2" class="data row7 col2" >12053.901862</td>
#       <td id="T_629a9_row7_col3" class="data row7 col3" >12175.756726</td>
#       <td id="T_629a9_row7_col4" class="data row7 col4" >11932.046999</td>
#       <td id="T_629a9_row7_col5" class="data row7 col5" >-30.463716</td>
#       <td id="T_629a9_row7_col6" class="data row7 col6" >11901.583283</td>
#       <td id="T_629a9_row7_col7" class="data row7 col7" >-2.583283</td>
#       <td id="T_629a9_row7_col8" class="data row7 col8" >2.583283</td>
#       <td id="T_629a9_row7_col9" class="data row7 col9" >6.673352</td>
#       <td id="T_629a9_row7_col10" class="data row7 col10" >0.021710</td>
#     </tr>
#     <tr>
#       <td id="T_629a9_row8_col0" class="data row8 col0" >2018-09-01 00:00:00</td>
#       <td id="T_629a9_row8_col1" class="data row8 col1" >11900.000000</td>
#       <td id="T_629a9_row8_col2" class="data row8 col2" >12023.121490</td>
#       <td id="T_629a9_row8_col3" class="data row8 col3" >12145.229679</td>
#       <td id=
# ===== HASIL EVALUASI =====
# MAE  : 162.22
# MSE  : 54036.42
# MAPE : 1.37%
