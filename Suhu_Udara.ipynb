# %% [markdown]
# # SINGLE MOVING AVERAGE 3 BULAN

# %%
# ==========================================
# IMPORT LIBRARY
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt

# ==========================================
# MEMBACA FILE EXCEL
# ==========================================

df = pd.read_excel(
    "Data.xlsx",
    sheet_name="Suhu_Udara"
)

# print("================ DATA AWAL ================")
# display(df.style.hide(axis="index"))

# ==========================================
# SINGLE MOVING AVERAGE 3 BULAN
# ==========================================

periode = 3

# Nilai St (Forecast)
df["St"] = (
    df["Suhu Udara (°C) (X1)"]
    .rolling(window=periode)
    .mean()
    .shift(1)
)

# ==========================================
# MENGHITUNG ERROR
# ==========================================

# Error
df["Xt-St"] = df["Suhu Udara (°C) (X1)"] - df["St"]

# Nilai Absolut Error
df["|Xt-St|"] = df["Xt-St"].abs()

# Kuadrat Error
df["(Xt-St)^2"] = df["Xt-St"] ** 2

# Absolute Percentage Error
df["APE (%)"] = (df["|Xt-St|"] / df["Suhu Udara (°C) (X1)"]) * 100

print("\n===== HASIL SINGLE MOVING AVERAGE 3 BULAN =====")
display(df.style.hide(axis="index"))

# ==========================================
# MENGHITUNG MAE, MSE, DAN MAPE
# ==========================================

hasil = df.dropna()

mae = hasil["|Xt-St|"].mean()

mse = hasil["(Xt-St)^2"].mean()

mape = hasil["APE (%)"].mean()

print("\n===== HASIL EVALUASI =====")
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"MAPE : {mape:.2f}%")

# ==========================================
# VISUALISASI
# ==========================================

plt.figure(figsize=(10,5))

plt.plot(
    df["Bulan"],
    df["Suhu Udara (°C) (X1)"],
    marker='o',
    linewidth=2,
    label="Data Aktual"
)

plt.plot(
    df["Bulan"],
    df["St"],
    marker='s',
    linewidth=2,
    label="Single Moving Average"
)

plt.title("Single Moving Average Suhu Udara")
plt.xlabel("Bulan")
plt.ylabel("Suhu Udara (°C)")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== HASIL SINGLE MOVING AVERAGE 3 BULAN =====
# <style type="text/css">
# </style>
# <table id="T_988ff">
#   <thead>
#     <tr>
#       <th id="T_988ff_level0_col0" class="col_heading level0 col0" >Bulan</th>
#       <th id="T_988ff_level0_col1" class="col_heading level0 col1" >Suhu Udara (°C) (X1)</th>
#       <th id="T_988ff_level0_col2" class="col_heading level0 col2" >St</th>
#       <th id="T_988ff_level0_col3" class="col_heading level0 col3" >Xt-St</th>
#       <th id="T_988ff_level0_col4" class="col_heading level0 col4" >|Xt-St|</th>
#       <th id="T_988ff_level0_col5" class="col_heading level0 col5" >(Xt-St)^2</th>
#       <th id="T_988ff_level0_col6" class="col_heading level0 col6" >APE (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_988ff_row0_col0" class="data row0 col0" >2018-01-01 00:00:00</td>
#       <td id="T_988ff_row0_col1" class="data row0 col1" >25.130000</td>
#       <td id="T_988ff_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_988ff_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_988ff_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_988ff_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_988ff_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row1_col0" class="data row1 col0" >2018-02-01 00:00:00</td>
#       <td id="T_988ff_row1_col1" class="data row1 col1" >25.360000</td>
#       <td id="T_988ff_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_988ff_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_988ff_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_988ff_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_988ff_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row2_col0" class="data row2 col0" >2018-03-01 00:00:00</td>
#       <td id="T_988ff_row2_col1" class="data row2 col1" >25.560000</td>
#       <td id="T_988ff_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_988ff_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_988ff_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_988ff_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_988ff_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row3_col0" class="data row3 col0" >2018-04-01 00:00:00</td>
#       <td id="T_988ff_row3_col1" class="data row3 col1" >26.000000</td>
#       <td id="T_988ff_row3_col2" class="data row3 col2" >25.350000</td>
#       <td id="T_988ff_row3_col3" class="data row3 col3" >0.650000</td>
#       <td id="T_988ff_row3_col4" class="data row3 col4" >0.650000</td>
#       <td id="T_988ff_row3_col5" class="data row3 col5" >0.422500</td>
#       <td id="T_988ff_row3_col6" class="data row3 col6" >2.500000</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row4_col0" class="data row4 col0" >2018-05-01 00:00:00</td>
#       <td id="T_988ff_row4_col1" class="data row4 col1" >25.460000</td>
#       <td id="T_988ff_row4_col2" class="data row4 col2" >25.640000</td>
#       <td id="T_988ff_row4_col3" class="data row4 col3" >-0.180000</td>
#       <td id="T_988ff_row4_col4" class="data row4 col4" >0.180000</td>
#       <td id="T_988ff_row4_col5" class="data row4 col5" >0.032400</td>
#       <td id="T_988ff_row4_col6" class="data row4 col6" >0.706991</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row5_col0" class="data row5 col0" >2018-06-01 00:00:00</td>
#       <td id="T_988ff_row5_col1" class="data row5 col1" >24.440000</td>
#       <td id="T_988ff_row5_col2" class="data row5 col2" >25.673333</td>
#       <td id="T_988ff_row5_col3" class="data row5 col3" >-1.233333</td>
#       <td id="T_988ff_row5_col4" class="data row5 col4" >1.233333</td>
#       <td id="T_988ff_row5_col5" class="data row5 col5" >1.521111</td>
#       <td id="T_988ff_row5_col6" class="data row5 col6" >5.046372</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row6_col0" class="data row6 col0" >2018-07-01 00:00:00</td>
#       <td id="T_988ff_row6_col1" class="data row6 col1" >22.750000</td>
#       <td id="T_988ff_row6_col2" class="data row6 col2" >25.300000</td>
#       <td id="T_988ff_row6_col3" class="data row6 col3" >-2.550000</td>
#       <td id="T_988ff_row6_col4" class="data row6 col4" >2.550000</td>
#       <td id="T_988ff_row6_col5" class="data row6 col5" >6.502500</td>
#       <td id="T_988ff_row6_col6" class="data row6 col6" >11.208791</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row7_col0" class="data row7 col0" >2018-08-01 00:00:00</td>
#       <td id="T_988ff_row7_col1" class="data row7 col1" >22.930000</td>
#       <td id="T_988ff_row7_col2" class="data row7 col2" >24.216667</td>
#       <td id="T_988ff_row7_col3" class="data row7 col3" >-1.286667</td>
#       <td id="T_988ff_row7_col4" class="data row7 col4" >1.286667</td>
#       <td id="T_988ff_row7_col5" class="data row7 col5" >1.655511</td>
#       <td id="T_988ff_row7_col6" class="data row7 col6" >5.611281</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row8_col0" class="data row8 col0" >2018-09-01 00:00:00</td>
#       <td id="T_988ff_row8_col1" class="data row8 col1" >24.750000</td>
#       <td id="T_988ff_row8_col2" class="data row8 col2" >23.373333</td>
#       <td id="T_988ff_row8_col3" class="data row8 col3" >1.376667</td>
#       <td id="T_988ff_row8_col4" class="data row8 col4" >1.376667</td>
#       <td id="T_988ff_row8_col5" class="data row8 col5" >1.895211</td>
#       <td id="T_988ff_row8_col6" class="data row8 col6" >5.562290</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row9_col0" class="data row9 col0" >2018-10-01 00:00:00</td>
#       <td id="T_988ff_row9_col1" class="data row9 col1" >26.240000</td>
#       <td id="T_988ff_row9_col2" class="data row9 col2" >23.476667</td>
#       <td id="T_988ff_row9_col3" class="data row9 col3" >2.763333</td>
#       <td id="T_988ff_row9_col4" class="data row9 col4" >2.763333</td>
#       <td id="T_988ff_row9_col5" class="data row9 col5" >7.636011</td>
#       <td id="T_988ff_row9_col6" class="data row9 col6" >10.530996</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row10_col0" class="data row10 col0" >2018-11-01 00:00:00</td>
#       <td id="T_988ff_row10_col1" class="data row10 col1" >25.700000</td>
#       <td id="T_988ff_row10_col2" class="data row10 col2" >24.640000</td>
#       <td id="T_988ff_row10_col3" class="data row10 col3" >1.060000</td>
#       <td id="T_988ff_row10_col4" class="data row10 col4" >1.060000</td>
#       <td id="T_988ff_row10_col5" class="data row10 col5" >1.123600</td>
#       <td id="T_988ff_row10_col6" class="data row10 col6" >4.124514</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row11_col0" class="data row11 col0" >2018-12-01 00:00:00</td>
#       <td id="T_988ff_row11_col1" class="data row11 col1" >25.470000</td>
#       <td id="T_988ff_row11_col2" class="data row11 col2" >25.563333</td>
#       <td id="T_988ff_row11_col3" class="data row11 col3" >-0.093333</td>
#       <td id="T_988ff_row11_col4" class="data row11 col4" >0.093333</td>
#       <td id="T_988ff_row11_col5" class="data row11 col5" >0.008711</td>
#       <td id="T_988ff_row11_col6" class="data row11 col6" >0.366444</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row12_col0" class="data row12 col0" >2019-01-01 00:00:00</td>
#       <td id="T_988ff_row12_col1" class="data row12 col1" >26.000000</td>
#       <td id="T_988ff_row12_col2" class="data row12 col2" >25.803333</td>
#       <td id="T_988ff_row12_col3" class="data row12 col3" >0.196667</td>
#       <td id="T_988ff_row12_col4" class="data row12 col4" >0.196667</td>
#       <td id="T_988ff_row12_col5" class="data row12 col5" >0.038678</td>
#       <td id="T_988ff_row12_col6" class="data row12 col6" >0.756410</td>
#     </tr>
#     <tr>
#       <td id="T_988ff_row13_col0" class="data row13 col0" >2019-02-01 00:00:00</td>
#       <td id="T_988ff_row13_col1" class="data row13 col1" >26.060000</td>
#       <td id="T_988ff_row13_col2" class="data row13 col2" >25.723333</td>
#       <td id="T_988ff_row13_col3" class="data row13 col3" >0.336667</td>
#       <td id="T_988ff_row13_col4" class="data row13 col4" >0.336667</td>
#       <td id="T_988ff_row13_col5" class="data row13 col5" >0.113344</td>
#       <td id="T
# ===== HASIL EVALUASI =====
# MAE  : 0.72
# MSE  : 0.98
# MAPE : 2.86%

# %% [markdown]
# # SINGLE MOVING AVERAGE 5 BULAN

# %%
# ==========================================
# IMPORT LIBRARY
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt

# ==========================================
# MEMBACA FILE EXCEL
# ==========================================

df = pd.read_excel(
    "Data.xlsx",
    sheet_name="Suhu_Udara"
)

# print("================ DATA AWAL ================")
# display(df.style.hide(axis="index"))

# ==========================================
# SINGLE MOVING AVERAGE 5 BULAN
# ==========================================

periode = 5

# Nilai St (Forecast)
df["St"] = (
    df["Suhu Udara (°C) (X1)"]
    .rolling(window=periode)
    .mean()
    .shift(1)
)

# ==========================================
# MENGHITUNG ERROR
# ==========================================

# Error
df["Xt-St"] = df["Suhu Udara (°C) (X1)"] - df["St"]

# Nilai Absolut Error
df["|Xt-St|"] = df["Xt-St"].abs()

# Kuadrat Error
df["(Xt-St)^2"] = df["Xt-St"] ** 2

# Absolute Percentage Error
df["APE (%)"] = (df["|Xt-St|"] / df["Suhu Udara (°C) (X1)"]) * 100

print("\n===== HASIL SINGLE MOVING AVERAGE 5 BULAN =====")
display(df.style.hide(axis="index"))

# ==========================================
# MENGHITUNG MAE, MSE, DAN MAPE
# ==========================================

hasil = df.dropna()

mae = hasil["|Xt-St|"].mean()

mse = hasil["(Xt-St)^2"].mean()

mape = hasil["APE (%)"].mean()

print("\n===== HASIL EVALUASI =====")
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"MAPE : {mape:.2f}%")

# ==========================================
# VISUALISASI
# ==========================================

plt.figure(figsize=(10,5))

plt.plot(
    df["Bulan"],
    df["Suhu Udara (°C) (X1)"],
    marker='o',
    linewidth=2,
    label="Data Aktual"
)

plt.plot(
    df["Bulan"],
    df["St"],
    marker='s',
    linewidth=2,
    label="SMA 5 Bulan"
)

plt.title("Single Moving Average 5 Bulan Suhu Udara (°C)")
plt.xlabel("Bulan")
plt.ylabel("Suhu Udara (°C)")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== HASIL SINGLE MOVING AVERAGE 5 BULAN =====
# <style type="text/css">
# </style>
# <table id="T_d1ea8">
#   <thead>
#     <tr>
#       <th id="T_d1ea8_level0_col0" class="col_heading level0 col0" >Bulan</th>
#       <th id="T_d1ea8_level0_col1" class="col_heading level0 col1" >Suhu Udara (°C) (X1)</th>
#       <th id="T_d1ea8_level0_col2" class="col_heading level0 col2" >St</th>
#       <th id="T_d1ea8_level0_col3" class="col_heading level0 col3" >Xt-St</th>
#       <th id="T_d1ea8_level0_col4" class="col_heading level0 col4" >|Xt-St|</th>
#       <th id="T_d1ea8_level0_col5" class="col_heading level0 col5" >(Xt-St)^2</th>
#       <th id="T_d1ea8_level0_col6" class="col_heading level0 col6" >APE (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d1ea8_row0_col0" class="data row0 col0" >2018-01-01 00:00:00</td>
#       <td id="T_d1ea8_row0_col1" class="data row0 col1" >25.130000</td>
#       <td id="T_d1ea8_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_d1ea8_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_d1ea8_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_d1ea8_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_d1ea8_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row1_col0" class="data row1 col0" >2018-02-01 00:00:00</td>
#       <td id="T_d1ea8_row1_col1" class="data row1 col1" >25.360000</td>
#       <td id="T_d1ea8_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_d1ea8_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_d1ea8_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_d1ea8_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_d1ea8_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row2_col0" class="data row2 col0" >2018-03-01 00:00:00</td>
#       <td id="T_d1ea8_row2_col1" class="data row2 col1" >25.560000</td>
#       <td id="T_d1ea8_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_d1ea8_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_d1ea8_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_d1ea8_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_d1ea8_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row3_col0" class="data row3 col0" >2018-04-01 00:00:00</td>
#       <td id="T_d1ea8_row3_col1" class="data row3 col1" >26.000000</td>
#       <td id="T_d1ea8_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_d1ea8_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_d1ea8_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_d1ea8_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_d1ea8_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row4_col0" class="data row4 col0" >2018-05-01 00:00:00</td>
#       <td id="T_d1ea8_row4_col1" class="data row4 col1" >25.460000</td>
#       <td id="T_d1ea8_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_d1ea8_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_d1ea8_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_d1ea8_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_d1ea8_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row5_col0" class="data row5 col0" >2018-06-01 00:00:00</td>
#       <td id="T_d1ea8_row5_col1" class="data row5 col1" >24.440000</td>
#       <td id="T_d1ea8_row5_col2" class="data row5 col2" >25.502000</td>
#       <td id="T_d1ea8_row5_col3" class="data row5 col3" >-1.062000</td>
#       <td id="T_d1ea8_row5_col4" class="data row5 col4" >1.062000</td>
#       <td id="T_d1ea8_row5_col5" class="data row5 col5" >1.127844</td>
#       <td id="T_d1ea8_row5_col6" class="data row5 col6" >4.345336</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row6_col0" class="data row6 col0" >2018-07-01 00:00:00</td>
#       <td id="T_d1ea8_row6_col1" class="data row6 col1" >22.750000</td>
#       <td id="T_d1ea8_row6_col2" class="data row6 col2" >25.364000</td>
#       <td id="T_d1ea8_row6_col3" class="data row6 col3" >-2.614000</td>
#       <td id="T_d1ea8_row6_col4" class="data row6 col4" >2.614000</td>
#       <td id="T_d1ea8_row6_col5" class="data row6 col5" >6.832996</td>
#       <td id="T_d1ea8_row6_col6" class="data row6 col6" >11.490110</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row7_col0" class="data row7 col0" >2018-08-01 00:00:00</td>
#       <td id="T_d1ea8_row7_col1" class="data row7 col1" >22.930000</td>
#       <td id="T_d1ea8_row7_col2" class="data row7 col2" >24.842000</td>
#       <td id="T_d1ea8_row7_col3" class="data row7 col3" >-1.912000</td>
#       <td id="T_d1ea8_row7_col4" class="data row7 col4" >1.912000</td>
#       <td id="T_d1ea8_row7_col5" class="data row7 col5" >3.655744</td>
#       <td id="T_d1ea8_row7_col6" class="data row7 col6" >8.338421</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row8_col0" class="data row8 col0" >2018-09-01 00:00:00</td>
#       <td id="T_d1ea8_row8_col1" class="data row8 col1" >24.750000</td>
#       <td id="T_d1ea8_row8_col2" class="data row8 col2" >24.316000</td>
#       <td id="T_d1ea8_row8_col3" class="data row8 col3" >0.434000</td>
#       <td id="T_d1ea8_row8_col4" class="data row8 col4" >0.434000</td>
#       <td id="T_d1ea8_row8_col5" class="data row8 col5" >0.188356</td>
#       <td id="T_d1ea8_row8_col6" class="data row8 col6" >1.753535</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row9_col0" class="data row9 col0" >2018-10-01 00:00:00</td>
#       <td id="T_d1ea8_row9_col1" class="data row9 col1" >26.240000</td>
#       <td id="T_d1ea8_row9_col2" class="data row9 col2" >24.066000</td>
#       <td id="T_d1ea8_row9_col3" class="data row9 col3" >2.174000</td>
#       <td id="T_d1ea8_row9_col4" class="data row9 col4" >2.174000</td>
#       <td id="T_d1ea8_row9_col5" class="data row9 col5" >4.726276</td>
#       <td id="T_d1ea8_row9_col6" class="data row9 col6" >8.285061</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row10_col0" class="data row10 col0" >2018-11-01 00:00:00</td>
#       <td id="T_d1ea8_row10_col1" class="data row10 col1" >25.700000</td>
#       <td id="T_d1ea8_row10_col2" class="data row10 col2" >24.222000</td>
#       <td id="T_d1ea8_row10_col3" class="data row10 col3" >1.478000</td>
#       <td id="T_d1ea8_row10_col4" class="data row10 col4" >1.478000</td>
#       <td id="T_d1ea8_row10_col5" class="data row10 col5" >2.184484</td>
#       <td id="T_d1ea8_row10_col6" class="data row10 col6" >5.750973</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row11_col0" class="data row11 col0" >2018-12-01 00:00:00</td>
#       <td id="T_d1ea8_row11_col1" class="data row11 col1" >25.470000</td>
#       <td id="T_d1ea8_row11_col2" class="data row11 col2" >24.474000</td>
#       <td id="T_d1ea8_row11_col3" class="data row11 col3" >0.996000</td>
#       <td id="T_d1ea8_row11_col4" class="data row11 col4" >0.996000</td>
#       <td id="T_d1ea8_row11_col5" class="data row11 col5" >0.992016</td>
#       <td id="T_d1ea8_row11_col6" class="data row11 col6" >3.910483</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row12_col0" class="data row12 col0" >2019-01-01 00:00:00</td>
#       <td id="T_d1ea8_row12_col1" class="data row12 col1" >26.000000</td>
#       <td id="T_d1ea8_row12_col2" class="data row12 col2" >25.018000</td>
#       <td id="T_d1ea8_row12_col3" class="data row12 col3" >0.982000</td>
#       <td id="T_d1ea8_row12_col4" class="data row12 col4" >0.982000</td>
#       <td id="T_d1ea8_row12_col5" class="data row12 col5" >0.964324</td>
#       <td id="T_d1ea8_row12_col6" class="data row12 col6" >3.776923</td>
#     </tr>
#     <tr>
#       <td id="T_d1ea8_row13_col0" class="data row13 col0" >2019-02-01 00:00:00</td>
#       <td id="T_d1ea8_row13_col1" class="data row13 col1" >26.060000</td>
#       <td id="T_d1ea8_row13_col2" class="data row13 col2" >25.632000</td>
#       <td id="T_d1ea8_row13_col3" class="data row13 col3" >0.428000</td>
#       <td id="T_d1ea8_row13_col4" class="data row13 col4" >0.428000</td>
#       <td id="T_d1ea8_row13_col5" class="data row13 col5" >0.183184</td>
#       <td id="T_d1ea8_row13_col6" class="data row13 col6" >1.642364</t
# ===== HASIL EVALUASI =====
# MAE  : 0.77
# MSE  : 1.10
# MAPE : 3.09%

# %% [markdown]
# # DOUBLE MOVING AVERAGE

# %%
# ==========================================
# IMPORT LIBRARY
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error
)

# ==========================================
# MEMBACA FILE EXCEL
# ==========================================

df = pd.read_excel(
    "Data.xlsx",
    sheet_name="Suhu_Udara"
)

# print("===== DATA AWAL =====")
# display(df.style.hide(axis="index"))

# ==========================================
# DOUBLE MOVING AVERAGE (3 BULAN)
# ==========================================

periode = 3

# Moving Average Pertama (M1)
df["M1"] = (
    df["Suhu Udara (°C) (X1)"]
    .rolling(window=periode)
    .mean()
)

# Moving Average Kedua (M2)
df["M2"] = (
    df["M1"]
    .rolling(window=periode)
    .mean()
)

# Nilai a
df["a"] = (2 * df["M1"]) - df["M2"]

# Nilai b
df["b"] = (2 / (periode - 1)) * (df["M1"] - df["M2"])

# Forecast periode berikutnya (m = 1)
df["Forecast"] = df["a"] + df["b"]

print("\n===== HASIL DOUBLE MOVING AVERAGE =====")
display(df.style.hide(axis="index"))

# ==========================================
# MENGHITUNG MAE, MSE DAN MAPE 
# ==========================================

hasil = df.dropna()

# Menghitung MAE
mae = mean_absolute_error(
    hasil["Suhu Udara (°C) (X1)"],
    hasil["Forecast"]
)

# Menghitung MSE
mse = mean_squared_error(
    hasil["Suhu Udara (°C) (X1)"],
    hasil["Forecast"]
)

# Menghitung MAPE
mape = mean_absolute_percentage_error(
    hasil["Suhu Udara (°C) (X1)"],
    hasil["Forecast"]
) * 100

print("\n===== HASIL EVALUASI =====")
print(f"MAE : {mae:.2f}")
print(f"MSE : {mse:.2f}")
print(f"MAPE : {mape:.2f}%")

# ==========================================
# VISUALISASI
# ==========================================

plt.figure(figsize=(10,5))

plt.plot(
    df["Bulan"],
    df["Suhu Udara (°C) (X1)"],
    marker='o',
    linewidth=2,
    label="Data Aktual"
)

plt.plot(
    df["Bulan"],
    df["Forecast"],
    marker='s',
    linewidth=2,
    label="Forecast DMA"
)

plt.title("Double Moving Average Suhu Udara")
plt.xlabel("Bulan")
plt.ylabel("Suhu Udara (°C)")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== HASIL DOUBLE MOVING AVERAGE =====
# <style type="text/css">
# </style>
# <table id="T_94ede">
#   <thead>
#     <tr>
#       <th id="T_94ede_level0_col0" class="col_heading level0 col0" >Bulan</th>
#       <th id="T_94ede_level0_col1" class="col_heading level0 col1" >Suhu Udara (°C) (X1)</th>
#       <th id="T_94ede_level0_col2" class="col_heading level0 col2" >M1</th>
#       <th id="T_94ede_level0_col3" class="col_heading level0 col3" >M2</th>
#       <th id="T_94ede_level0_col4" class="col_heading level0 col4" >a</th>
#       <th id="T_94ede_level0_col5" class="col_heading level0 col5" >b</th>
#       <th id="T_94ede_level0_col6" class="col_heading level0 col6" >Forecast</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_94ede_row0_col0" class="data row0 col0" >2018-01-01 00:00:00</td>
#       <td id="T_94ede_row0_col1" class="data row0 col1" >25.130000</td>
#       <td id="T_94ede_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_94ede_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_94ede_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_94ede_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_94ede_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row1_col0" class="data row1 col0" >2018-02-01 00:00:00</td>
#       <td id="T_94ede_row1_col1" class="data row1 col1" >25.360000</td>
#       <td id="T_94ede_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_94ede_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_94ede_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_94ede_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_94ede_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row2_col0" class="data row2 col0" >2018-03-01 00:00:00</td>
#       <td id="T_94ede_row2_col1" class="data row2 col1" >25.560000</td>
#       <td id="T_94ede_row2_col2" class="data row2 col2" >25.350000</td>
#       <td id="T_94ede_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_94ede_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_94ede_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_94ede_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row3_col0" class="data row3 col0" >2018-04-01 00:00:00</td>
#       <td id="T_94ede_row3_col1" class="data row3 col1" >26.000000</td>
#       <td id="T_94ede_row3_col2" class="data row3 col2" >25.640000</td>
#       <td id="T_94ede_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_94ede_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_94ede_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_94ede_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row4_col0" class="data row4 col0" >2018-05-01 00:00:00</td>
#       <td id="T_94ede_row4_col1" class="data row4 col1" >25.460000</td>
#       <td id="T_94ede_row4_col2" class="data row4 col2" >25.673333</td>
#       <td id="T_94ede_row4_col3" class="data row4 col3" >25.554444</td>
#       <td id="T_94ede_row4_col4" class="data row4 col4" >25.792222</td>
#       <td id="T_94ede_row4_col5" class="data row4 col5" >0.118889</td>
#       <td id="T_94ede_row4_col6" class="data row4 col6" >25.911111</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row5_col0" class="data row5 col0" >2018-06-01 00:00:00</td>
#       <td id="T_94ede_row5_col1" class="data row5 col1" >24.440000</td>
#       <td id="T_94ede_row5_col2" class="data row5 col2" >25.300000</td>
#       <td id="T_94ede_row5_col3" class="data row5 col3" >25.537778</td>
#       <td id="T_94ede_row5_col4" class="data row5 col4" >25.062222</td>
#       <td id="T_94ede_row5_col5" class="data row5 col5" >-0.237778</td>
#       <td id="T_94ede_row5_col6" class="data row5 col6" >24.824444</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row6_col0" class="data row6 col0" >2018-07-01 00:00:00</td>
#       <td id="T_94ede_row6_col1" class="data row6 col1" >22.750000</td>
#       <td id="T_94ede_row6_col2" class="data row6 col2" >24.216667</td>
#       <td id="T_94ede_row6_col3" class="data row6 col3" >25.063333</td>
#       <td id="T_94ede_row6_col4" class="data row6 col4" >23.370000</td>
#       <td id="T_94ede_row6_col5" class="data row6 col5" >-0.846667</td>
#       <td id="T_94ede_row6_col6" class="data row6 col6" >22.523333</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row7_col0" class="data row7 col0" >2018-08-01 00:00:00</td>
#       <td id="T_94ede_row7_col1" class="data row7 col1" >22.930000</td>
#       <td id="T_94ede_row7_col2" class="data row7 col2" >23.373333</td>
#       <td id="T_94ede_row7_col3" class="data row7 col3" >24.296667</td>
#       <td id="T_94ede_row7_col4" class="data row7 col4" >22.450000</td>
#       <td id="T_94ede_row7_col5" class="data row7 col5" >-0.923333</td>
#       <td id="T_94ede_row7_col6" class="data row7 col6" >21.526667</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row8_col0" class="data row8 col0" >2018-09-01 00:00:00</td>
#       <td id="T_94ede_row8_col1" class="data row8 col1" >24.750000</td>
#       <td id="T_94ede_row8_col2" class="data row8 col2" >23.476667</td>
#       <td id="T_94ede_row8_col3" class="data row8 col3" >23.688889</td>
#       <td id="T_94ede_row8_col4" class="data row8 col4" >23.264444</td>
#       <td id="T_94ede_row8_col5" class="data row8 col5" >-0.212222</td>
#       <td id="T_94ede_row8_col6" class="data row8 col6" >23.052222</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row9_col0" class="data row9 col0" >2018-10-01 00:00:00</td>
#       <td id="T_94ede_row9_col1" class="data row9 col1" >26.240000</td>
#       <td id="T_94ede_row9_col2" class="data row9 col2" >24.640000</td>
#       <td id="T_94ede_row9_col3" class="data row9 col3" >23.830000</td>
#       <td id="T_94ede_row9_col4" class="data row9 col4" >25.450000</td>
#       <td id="T_94ede_row9_col5" class="data row9 col5" >0.810000</td>
#       <td id="T_94ede_row9_col6" class="data row9 col6" >26.260000</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row10_col0" class="data row10 col0" >2018-11-01 00:00:00</td>
#       <td id="T_94ede_row10_col1" class="data row10 col1" >25.700000</td>
#       <td id="T_94ede_row10_col2" class="data row10 col2" >25.563333</td>
#       <td id="T_94ede_row10_col3" class="data row10 col3" >24.560000</td>
#       <td id="T_94ede_row10_col4" class="data row10 col4" >26.566667</td>
#       <td id="T_94ede_row10_col5" class="data row10 col5" >1.003333</td>
#       <td id="T_94ede_row10_col6" class="data row10 col6" >27.570000</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row11_col0" class="data row11 col0" >2018-12-01 00:00:00</td>
#       <td id="T_94ede_row11_col1" class="data row11 col1" >25.470000</td>
#       <td id="T_94ede_row11_col2" class="data row11 col2" >25.803333</td>
#       <td id="T_94ede_row11_col3" class="data row11 col3" >25.335556</td>
#       <td id="T_94ede_row11_col4" class="data row11 col4" >26.271111</td>
#       <td id="T_94ede_row11_col5" class="data row11 col5" >0.467778</td>
#       <td id="T_94ede_row11_col6" class="data row11 col6" >26.738889</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row12_col0" class="data row12 col0" >2019-01-01 00:00:00</td>
#       <td id="T_94ede_row12_col1" class="data row12 col1" >26.000000</td>
#       <td id="T_94ede_row12_col2" class="data row12 col2" >25.723333</td>
#       <td id="T_94ede_row12_col3" class="data row12 col3" >25.696667</td>
#       <td id="T_94ede_row12_col4" class="data row12 col4" >25.750000</td>
#       <td id="T_94ede_row12_col5" class="data row12 col5" >0.026667</td>
#       <td id="T_94ede_row12_col6" class="data row12 col6" >25.776667</td>
#     </tr>
#     <tr>
#       <td id="T_94ede_row13_col0" class="data row13 col0" >2019-02-01 00:00:00</td>
#       <td id="T_94ede_row13_col1" class="data row13 col1" >26.060000</td>
#       <td id="T_94ede_row13_col2" class="data row13 col2" >25.843333</td>
#       <td id="T_94ede_row13_col3" class="data row13 col3" >25.790000</td>
#       <td id="T_94ede_row13_col4" class="data row13 col4" >25.896667</td>
#       <td id="T_94ede_row13_col5" class="data row13 col5" >0.053333</td>
#       <td id="T_94e
# ===== HASIL EVALUASI =====
# MAE : 0.49
# MSE : 0.46
# MAPE : 1.93%

# %% [markdown]
# # SINGLE EXPONENTIAL SMOOTHING

# %%
# ==========================================
# IMPORT LIBRARY
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error
)

# ==========================================
# MEMBACA FILE EXCEL
# ==========================================

df = pd.read_excel(
    "Data.xlsx",
    sheet_name="Suhu_Udara"
)

# print("===== DATA AWAL =====")
# display(df.style.hide(axis="index"))

# ==========================================
# SINGLE EXPONENTIAL SMOOTHING
# ==========================================

# Mengubah Nilai Alpha (0.10) dan (0.50)
alpha = 0.5

# ==========================================
# PERHITUNGAN SINGLE EXPONENTIAL SMOOTHING
# ==========================================

# Kolom St (hasil smoothing)
df["St"] = 0.0

# Nilai awal St = data aktual pertama
df.loc[0, "St"] = df.loc[0, "Suhu Udara (°C) (X1)"]

# Menghitung nilai St
for i in range(1, len(df)):
    df.loc[i, "St"] = (
        alpha * df.loc[i-1, "Suhu Udara (°C) (X1)"]
        + (1 - alpha) * df.loc[i-1, "St"]
    )

# ==========================================
# PERHITUNGAN ERROR
# ==========================================

# Error
df["Xt-St"] = df["Suhu Udara (°C) (X1)"] - df["St"]

# Nilai Absolut Error
df["|Xt-St|"] = df["Xt-St"].abs()

# Kuadrat Error
df["(Xt-St)^2"] = df["Xt-St"] ** 2

print("\n===== HASIL SINGLE EXPONENTIAL SMOOTHING =====")
display(df.style.hide(axis="index"))

# ==========================================
# MENGHITUNG MAE, MSE, DAN MAPE
# ==========================================

hasil = df.iloc[1:]

mae = hasil["|Xt-St|"].mean()

mse = hasil["(Xt-St)^2"].mean()

mape = (
    (hasil["|Xt-St|"] / hasil["Suhu Udara (°C) (X1)"])
    .mean()
) * 100

print("\n===== HASIL EVALUASI =====")
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"MAPE : {mape:.2f}%")

# ==========================================
# VISUALISASI
# ==========================================

plt.figure(figsize=(10,5))

plt.plot(
    df["Bulan"],
    df["Suhu Udara (°C) (X1)"],
    marker='o',
    linewidth=2,
    label="Data Aktual"
)

plt.plot(
    df["Bulan"],
    df["St"],
    marker='s',
    linewidth=2,
    label=f"SES (α = {alpha})"
)

plt.title("Single Exponential Smoothing Suhu Udara")
plt.xlabel("Bulan")
plt.ylabel("Suhu Udara (°C)")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== HASIL SINGLE EXPONENTIAL SMOOTHING =====
# <style type="text/css">
# </style>
# <table id="T_fbfbd">
#   <thead>
#     <tr>
#       <th id="T_fbfbd_level0_col0" class="col_heading level0 col0" >Bulan</th>
#       <th id="T_fbfbd_level0_col1" class="col_heading level0 col1" >Suhu Udara (°C) (X1)</th>
#       <th id="T_fbfbd_level0_col2" class="col_heading level0 col2" >St</th>
#       <th id="T_fbfbd_level0_col3" class="col_heading level0 col3" >Xt-St</th>
#       <th id="T_fbfbd_level0_col4" class="col_heading level0 col4" >|Xt-St|</th>
#       <th id="T_fbfbd_level0_col5" class="col_heading level0 col5" >(Xt-St)^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fbfbd_row0_col0" class="data row0 col0" >2018-01-01 00:00:00</td>
#       <td id="T_fbfbd_row0_col1" class="data row0 col1" >25.130000</td>
#       <td id="T_fbfbd_row0_col2" class="data row0 col2" >25.130000</td>
#       <td id="T_fbfbd_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_fbfbd_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_fbfbd_row0_col5" class="data row0 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row1_col0" class="data row1 col0" >2018-02-01 00:00:00</td>
#       <td id="T_fbfbd_row1_col1" class="data row1 col1" >25.360000</td>
#       <td id="T_fbfbd_row1_col2" class="data row1 col2" >25.130000</td>
#       <td id="T_fbfbd_row1_col3" class="data row1 col3" >0.230000</td>
#       <td id="T_fbfbd_row1_col4" class="data row1 col4" >0.230000</td>
#       <td id="T_fbfbd_row1_col5" class="data row1 col5" >0.052900</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row2_col0" class="data row2 col0" >2018-03-01 00:00:00</td>
#       <td id="T_fbfbd_row2_col1" class="data row2 col1" >25.560000</td>
#       <td id="T_fbfbd_row2_col2" class="data row2 col2" >25.245000</td>
#       <td id="T_fbfbd_row2_col3" class="data row2 col3" >0.315000</td>
#       <td id="T_fbfbd_row2_col4" class="data row2 col4" >0.315000</td>
#       <td id="T_fbfbd_row2_col5" class="data row2 col5" >0.099225</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row3_col0" class="data row3 col0" >2018-04-01 00:00:00</td>
#       <td id="T_fbfbd_row3_col1" class="data row3 col1" >26.000000</td>
#       <td id="T_fbfbd_row3_col2" class="data row3 col2" >25.402500</td>
#       <td id="T_fbfbd_row3_col3" class="data row3 col3" >0.597500</td>
#       <td id="T_fbfbd_row3_col4" class="data row3 col4" >0.597500</td>
#       <td id="T_fbfbd_row3_col5" class="data row3 col5" >0.357006</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row4_col0" class="data row4 col0" >2018-05-01 00:00:00</td>
#       <td id="T_fbfbd_row4_col1" class="data row4 col1" >25.460000</td>
#       <td id="T_fbfbd_row4_col2" class="data row4 col2" >25.701250</td>
#       <td id="T_fbfbd_row4_col3" class="data row4 col3" >-0.241250</td>
#       <td id="T_fbfbd_row4_col4" class="data row4 col4" >0.241250</td>
#       <td id="T_fbfbd_row4_col5" class="data row4 col5" >0.058202</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row5_col0" class="data row5 col0" >2018-06-01 00:00:00</td>
#       <td id="T_fbfbd_row5_col1" class="data row5 col1" >24.440000</td>
#       <td id="T_fbfbd_row5_col2" class="data row5 col2" >25.580625</td>
#       <td id="T_fbfbd_row5_col3" class="data row5 col3" >-1.140625</td>
#       <td id="T_fbfbd_row5_col4" class="data row5 col4" >1.140625</td>
#       <td id="T_fbfbd_row5_col5" class="data row5 col5" >1.301025</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row6_col0" class="data row6 col0" >2018-07-01 00:00:00</td>
#       <td id="T_fbfbd_row6_col1" class="data row6 col1" >22.750000</td>
#       <td id="T_fbfbd_row6_col2" class="data row6 col2" >25.010312</td>
#       <td id="T_fbfbd_row6_col3" class="data row6 col3" >-2.260312</td>
#       <td id="T_fbfbd_row6_col4" class="data row6 col4" >2.260312</td>
#       <td id="T_fbfbd_row6_col5" class="data row6 col5" >5.109013</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row7_col0" class="data row7 col0" >2018-08-01 00:00:00</td>
#       <td id="T_fbfbd_row7_col1" class="data row7 col1" >22.930000</td>
#       <td id="T_fbfbd_row7_col2" class="data row7 col2" >23.880156</td>
#       <td id="T_fbfbd_row7_col3" class="data row7 col3" >-0.950156</td>
#       <td id="T_fbfbd_row7_col4" class="data row7 col4" >0.950156</td>
#       <td id="T_fbfbd_row7_col5" class="data row7 col5" >0.902797</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row8_col0" class="data row8 col0" >2018-09-01 00:00:00</td>
#       <td id="T_fbfbd_row8_col1" class="data row8 col1" >24.750000</td>
#       <td id="T_fbfbd_row8_col2" class="data row8 col2" >23.405078</td>
#       <td id="T_fbfbd_row8_col3" class="data row8 col3" >1.344922</td>
#       <td id="T_fbfbd_row8_col4" class="data row8 col4" >1.344922</td>
#       <td id="T_fbfbd_row8_col5" class="data row8 col5" >1.808815</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row9_col0" class="data row9 col0" >2018-10-01 00:00:00</td>
#       <td id="T_fbfbd_row9_col1" class="data row9 col1" >26.240000</td>
#       <td id="T_fbfbd_row9_col2" class="data row9 col2" >24.077539</td>
#       <td id="T_fbfbd_row9_col3" class="data row9 col3" >2.162461</td>
#       <td id="T_fbfbd_row9_col4" class="data row9 col4" >2.162461</td>
#       <td id="T_fbfbd_row9_col5" class="data row9 col5" >4.676237</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row10_col0" class="data row10 col0" >2018-11-01 00:00:00</td>
#       <td id="T_fbfbd_row10_col1" class="data row10 col1" >25.700000</td>
#       <td id="T_fbfbd_row10_col2" class="data row10 col2" >25.158770</td>
#       <td id="T_fbfbd_row10_col3" class="data row10 col3" >0.541230</td>
#       <td id="T_fbfbd_row10_col4" class="data row10 col4" >0.541230</td>
#       <td id="T_fbfbd_row10_col5" class="data row10 col5" >0.292930</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row11_col0" class="data row11 col0" >2018-12-01 00:00:00</td>
#       <td id="T_fbfbd_row11_col1" class="data row11 col1" >25.470000</td>
#       <td id="T_fbfbd_row11_col2" class="data row11 col2" >25.429385</td>
#       <td id="T_fbfbd_row11_col3" class="data row11 col3" >0.040615</td>
#       <td id="T_fbfbd_row11_col4" class="data row11 col4" >0.040615</td>
#       <td id="T_fbfbd_row11_col5" class="data row11 col5" >0.001650</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row12_col0" class="data row12 col0" >2019-01-01 00:00:00</td>
#       <td id="T_fbfbd_row12_col1" class="data row12 col1" >26.000000</td>
#       <td id="T_fbfbd_row12_col2" class="data row12 col2" >25.449692</td>
#       <td id="T_fbfbd_row12_col3" class="data row12 col3" >0.550308</td>
#       <td id="T_fbfbd_row12_col4" class="data row12 col4" >0.550308</td>
#       <td id="T_fbfbd_row12_col5" class="data row12 col5" >0.302838</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row13_col0" class="data row13 col0" >2019-02-01 00:00:00</td>
#       <td id="T_fbfbd_row13_col1" class="data row13 col1" >26.060000</td>
#       <td id="T_fbfbd_row13_col2" class="data row13 col2" >25.724846</td>
#       <td id="T_fbfbd_row13_col3" class="data row13 col3" >0.335154</td>
#       <td id="T_fbfbd_row13_col4" class="data row13 col4" >0.335154</td>
#       <td id="T_fbfbd_row13_col5" class="data row13 col5" >0.112328</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row14_col0" class="data row14 col0" >2019-03-01 00:00:00</td>
#       <td id="T_fbfbd_row14_col1" class="data row14 col1" >25.340000</td>
#       <td id="T_fbfbd_row14_col2" class="data row14 col2" >25.892423</td>
#       <td id="T_fbfbd_row14_col3" class="data row14 col3" >-0.552423</td>
#       <td id="T_fbfbd_row14_col4" class="data row14 col4" >0.552423</td>
#       <td id="T_fbfbd_row14_col5" class="data row14 col5" >0.305171</td>
#     </tr>
#     <tr>
#       <td id="T_fbfbd_row15_col0" class="data row15 col0" >2019-04-01 00:00:00</td>
#       <td id="T_fbfbd_row15_col1" class="data row15 col1" >26.220000</td>
#       <td id="T_fbfbd_row15_col2" class="data row15 col2" >25.616212</td>
#       <td id="T_fbfbd_row15_col3" class="data row15 col3" >0.603788</td>
#       <td id="T_fbfbd_row15_col4" class="data row15 col4" >0.603788</td>
#       <td id="T_fbfbd_row15_col5" class="data row15 col5" >0.364560</td>
#     </tr>
# ===== HASIL EVALUASI =====
# MAE  : 0.61
# MSE  : 0.70
# MAPE : 2.42%

# %% [markdown]
# # DOUBLE EXPONENTIAL SMOOTHING

# %%
# ==========================================
# IMPORT LIBRARY
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt

# ==========================================
# MEMBACA FILE EXCEL
# ==========================================

df = pd.read_excel(
    "Data.xlsx",
    sheet_name="Suhu_Udara"
)

# print("================ DATA AWAL ================")
# display(df.style.hide(axis="index"))

# ==========================================
# PARAMETER
# ==========================================

alpha = 0.2

# ==========================================
# MEMBUAT KOLOM
# ==========================================

df["S't"] = 0.0
df["S''t"] = 0.0
df["a"] = 0.0
df["b"] = 0.0
df["Forecast"] = None

# ==========================================
# NILAI AWAL
# ==========================================

df.loc[0, "S't"] = df.loc[0, "Suhu Udara (°C) (X1)"]
df.loc[0, "S''t"] = df.loc[0, "Suhu Udara (°C) (X1)"]

# ==========================================
# PERHITUNGAN DOUBLE EXPONENTIAL SMOOTHING
# ==========================================

for i in range(1, len(df)):

    # Single Smoothing
    df.loc[i, "S't"] = (
        alpha * df.loc[i, "Suhu Udara (°C) (X1)"] +
        (1-alpha) * df.loc[i-1, "S't"]
    )

    # Double Smoothing
    df.loc[i, "S''t"] = (
        alpha * df.loc[i, "S't"] +
        (1-alpha) * df.loc[i-1, "S''t"]
    )

    # Nilai a
    df.loc[i, "a"] = (
        2 * df.loc[i, "S't"] -
        df.loc[i, "S''t"]
    )

    # Nilai b
    df.loc[i, "b"] = (
        alpha / (1-alpha)
    ) * (
        df.loc[i, "S't"] -
        df.loc[i, "S''t"]
    )

    # Forecast satu periode ke depan
    df.loc[i, "Forecast"] = (
        df.loc[i, "a"] +
        df.loc[i, "b"]
    )

# ==========================================
# MENGHITUNG ERROR
# ==========================================

df["Xt-Ft"] = (
    df["Suhu Udara (°C) (X1)"] -
    df["Forecast"]
)

df["|Xt-Ft|"] = df["Xt-Ft"].abs()

df["(Xt-Ft)^2"] = df["Xt-Ft"]**2

df["APE (%)"] = (
    df["|Xt-Ft|"] /
    df["Suhu Udara (°C) (X1)"]
) * 100

print("\n===== HASIL DOUBLE EXPONENTIAL SMOOTHING =====")
display(df.style.hide(axis="index"))

# ==========================================
# EVALUASI
# ==========================================

hasil = df.dropna()

mae = hasil["|Xt-Ft|"].mean()

mse = hasil["(Xt-Ft)^2"].mean()

mape = hasil["APE (%)"].mean()

print("\n===== HASIL EVALUASI =====")
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"MAPE : {mape:.2f}%")

# ==========================================
# VISUALISASI
# ==========================================

plt.figure(figsize=(10,5))

plt.plot(
    df["Bulan"],
    df["Suhu Udara (°C) (X1)"],
    marker='o',
    linewidth=2,
    label="Data Aktual"
)

plt.plot(
    df["Bulan"],
    df["Forecast"],
    marker='s',
    linewidth=2,
    label=f"DES Brown (α={alpha})"
)

plt.title("Double Exponential Smoothing Suhu Udara")
plt.xlabel("Bulan")
plt.ylabel("Suhu Udara (°C)")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== HASIL DOUBLE EXPONENTIAL SMOOTHING =====
# <style type="text/css">
# </style>
# <table id="T_e7419">
#   <thead>
#     <tr>
#       <th id="T_e7419_level0_col0" class="col_heading level0 col0" >Bulan</th>
#       <th id="T_e7419_level0_col1" class="col_heading level0 col1" >Suhu Udara (°C) (X1)</th>
#       <th id="T_e7419_level0_col2" class="col_heading level0 col2" >S't</th>
#       <th id="T_e7419_level0_col3" class="col_heading level0 col3" >S''t</th>
#       <th id="T_e7419_level0_col4" class="col_heading level0 col4" >a</th>
#       <th id="T_e7419_level0_col5" class="col_heading level0 col5" >b</th>
#       <th id="T_e7419_level0_col6" class="col_heading level0 col6" >Forecast</th>
#       <th id="T_e7419_level0_col7" class="col_heading level0 col7" >Xt-Ft</th>
#       <th id="T_e7419_level0_col8" class="col_heading level0 col8" >|Xt-Ft|</th>
#       <th id="T_e7419_level0_col9" class="col_heading level0 col9" >(Xt-Ft)^2</th>
#       <th id="T_e7419_level0_col10" class="col_heading level0 col10" >APE (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e7419_row0_col0" class="data row0 col0" >2018-01-01 00:00:00</td>
#       <td id="T_e7419_row0_col1" class="data row0 col1" >25.130000</td>
#       <td id="T_e7419_row0_col2" class="data row0 col2" >25.130000</td>
#       <td id="T_e7419_row0_col3" class="data row0 col3" >25.130000</td>
#       <td id="T_e7419_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_e7419_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_e7419_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_e7419_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_e7419_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_e7419_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_e7419_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_e7419_row1_col0" class="data row1 col0" >2018-02-01 00:00:00</td>
#       <td id="T_e7419_row1_col1" class="data row1 col1" >25.360000</td>
#       <td id="T_e7419_row1_col2" class="data row1 col2" >25.176000</td>
#       <td id="T_e7419_row1_col3" class="data row1 col3" >25.139200</td>
#       <td id="T_e7419_row1_col4" class="data row1 col4" >25.212800</td>
#       <td id="T_e7419_row1_col5" class="data row1 col5" >0.009200</td>
#       <td id="T_e7419_row1_col6" class="data row1 col6" >25.222000</td>
#       <td id="T_e7419_row1_col7" class="data row1 col7" >0.138000</td>
#       <td id="T_e7419_row1_col8" class="data row1 col8" >0.138000</td>
#       <td id="T_e7419_row1_col9" class="data row1 col9" >0.019044</td>
#       <td id="T_e7419_row1_col10" class="data row1 col10" >0.544164</td>
#     </tr>
#     <tr>
#       <td id="T_e7419_row2_col0" class="data row2 col0" >2018-03-01 00:00:00</td>
#       <td id="T_e7419_row2_col1" class="data row2 col1" >25.560000</td>
#       <td id="T_e7419_row2_col2" class="data row2 col2" >25.252800</td>
#       <td id="T_e7419_row2_col3" class="data row2 col3" >25.161920</td>
#       <td id="T_e7419_row2_col4" class="data row2 col4" >25.343680</td>
#       <td id="T_e7419_row2_col5" class="data row2 col5" >0.022720</td>
#       <td id="T_e7419_row2_col6" class="data row2 col6" >25.366400</td>
#       <td id="T_e7419_row2_col7" class="data row2 col7" >0.193600</td>
#       <td id="T_e7419_row2_col8" class="data row2 col8" >0.193600</td>
#       <td id="T_e7419_row2_col9" class="data row2 col9" >0.037481</td>
#       <td id="T_e7419_row2_col10" class="data row2 col10" >0.757433</td>
#     </tr>
#     <tr>
#       <td id="T_e7419_row3_col0" class="data row3 col0" >2018-04-01 00:00:00</td>
#       <td id="T_e7419_row3_col1" class="data row3 col1" >26.000000</td>
#       <td id="T_e7419_row3_col2" class="data row3 col2" >25.402240</td>
#       <td id="T_e7419_row3_col3" class="data row3 col3" >25.209984</td>
#       <td id="T_e7419_row3_col4" class="data row3 col4" >25.594496</td>
#       <td id="T_e7419_row3_col5" class="data row3 col5" >0.048064</td>
#       <td id="T_e7419_row3_col6" class="data row3 col6" >25.642560</td>
#       <td id="T_e7419_row3_col7" class="data row3 col7" >0.357440</td>
#       <td id="T_e7419_row3_col8" class="data row3 col8" >0.357440</td>
#       <td id="T_e7419_row3_col9" class="data row3 col9" >0.127763</td>
#       <td id="T_e7419_row3_col10" class="data row3 col10" >1.374769</td>
#     </tr>
#     <tr>
#       <td id="T_e7419_row4_col0" class="data row4 col0" >2018-05-01 00:00:00</td>
#       <td id="T_e7419_row4_col1" class="data row4 col1" >25.460000</td>
#       <td id="T_e7419_row4_col2" class="data row4 col2" >25.413792</td>
#       <td id="T_e7419_row4_col3" class="data row4 col3" >25.250746</td>
#       <td id="T_e7419_row4_col4" class="data row4 col4" >25.576838</td>
#       <td id="T_e7419_row4_col5" class="data row4 col5" >0.040762</td>
#       <td id="T_e7419_row4_col6" class="data row4 col6" >25.617600</td>
#       <td id="T_e7419_row4_col7" class="data row4 col7" >-0.157600</td>
#       <td id="T_e7419_row4_col8" class="data row4 col8" >0.157600</td>
#       <td id="T_e7419_row4_col9" class="data row4 col9" >0.024838</td>
#       <td id="T_e7419_row4_col10" class="data row4 col10" >0.619010</td>
#     </tr>
#     <tr>
#       <td id="T_e7419_row5_col0" class="data row5 col0" >2018-06-01 00:00:00</td>
#       <td id="T_e7419_row5_col1" class="data row5 col1" >24.440000</td>
#       <td id="T_e7419_row5_col2" class="data row5 col2" >25.219034</td>
#       <td id="T_e7419_row5_col3" class="data row5 col3" >25.244403</td>
#       <td id="T_e7419_row5_col4" class="data row5 col4" >25.193664</td>
#       <td id="T_e7419_row5_col5" class="data row5 col5" >-0.006342</td>
#       <td id="T_e7419_row5_col6" class="data row5 col6" >25.187322</td>
#       <td id="T_e7419_row5_col7" class="data row5 col7" >-0.747322</td>
#       <td id="T_e7419_row5_col8" class="data row5 col8" >0.747322</td>
#       <td id="T_e7419_row5_col9" class="data row5 col9" >0.558490</td>
#       <td id="T_e7419_row5_col10" class="data row5 col10" >3.057781</td>
#     </tr>
#     <tr>
#       <td id="T_e7419_row6_col0" class="data row6 col0" >2018-07-01 00:00:00</td>
#       <td id="T_e7419_row6_col1" class="data row6 col1" >22.750000</td>
#       <td id="T_e7419_row6_col2" class="data row6 col2" >24.725227</td>
#       <td id="T_e7419_row6_col3" class="data row6 col3" >25.140568</td>
#       <td id="T_e7419_row6_col4" class="data row6 col4" >24.309886</td>
#       <td id="T_e7419_row6_col5" class="data row6 col5" >-0.103835</td>
#       <td id="T_e7419_row6_col6" class="data row6 col6" >24.206051</td>
#       <td id="T_e7419_row6_col7" class="data row6 col7" >-1.456051</td>
#       <td id="T_e7419_row6_col8" class="data row6 col8" >1.456051</td>
#       <td id="T_e7419_row6_col9" class="data row6 col9" >2.120083</td>
#       <td id="T_e7419_row6_col10" class="data row6 col10" >6.400222</td>
#     </tr>
#     <tr>
#       <td id="T_e7419_row7_col0" class="data row7 col0" >2018-08-01 00:00:00</td>
#       <td id="T_e7419_row7_col1" class="data row7 col1" >22.930000</td>
#       <td id="T_e7419_row7_col2" class="data row7 col2" >24.366182</td>
#       <td id="T_e7419_row7_col3" class="data row7 col3" >24.985691</td>
#       <td id="T_e7419_row7_col4" class="data row7 col4" >23.746672</td>
#       <td id="T_e7419_row7_col5" class="data row7 col5" >-0.154877</td>
#       <td id="T_e7419_row7_col6" class="data row7 col6" >23.591795</td>
#       <td id="T_e7419_row7_col7" class="data row7 col7" >-0.661795</td>
#       <td id="T_e7419_row7_col8" class="data row7 col8" >0.661795</td>
#       <td id="T_e7419_row7_col9" class="data row7 col9" >0.437973</td>
#       <td id="T_e7419_row7_col10" class="data row7 col10" >2.886154</td>
#     </tr>
#     <tr>
#       <td id="T_e7419_row8_col0" class="data row8 col0" >2018-09-01 00:00:00</td>
#       <td id="T_e7419_row8_col1" class="data row8 col1" >24.750000</td>
#       <td id="T_e7419_row8_col2" class="data row8 col2" >24.442945</td>
#       <td id="T_e7419_row8_col3" class="data row8 col3" >24.877142</td>
#       <td id="T_e7419_row8_col4" class="data row8 col4" >24.008749</td>
#       <td id="T_e7419_row8_col5" class="data row8 col5" >-0.108549</td>
#       <td id="T_e7419_row8_col6" c
# ===== HASIL EVALUASI =====
# MAE  : 0.43
# MSE  : 0.34
# MAPE : 1.71%
